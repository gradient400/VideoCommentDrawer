# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
start_time_min = 10.0

# %%
from utils import CommentPool
comment_pool_config = {'discard_early_comments': True, 'time_offset': start_time_min*60}
comment_pool = CommentPool(comment_pool_config)
comment_pool.load_comments_from_json('../code_add_comments/chat_01_combined_with_BD_corr.json', ['x', '+', '++', '?'], zero_pointer_shift=-10)

# %%
comment_pool.comments[comment_pool.get_zero_time_pointer()]
# Out:
# {'idx': 1577,
#  'time': '00:10:00',
#  'Man': '红鞋子的话',
#  'content': '赤い靴なら',
#  'tBD': '红色的鞋子',
#  'tG': '红鞋子',
#  'tD': '如果是红鞋...',
#  'time_raw': 600.247}

# %%
comment_pool.pointer
# Out:
# 1517

# %%
comment_pool.comments[comment_pool.pointer]
# Out:
# {'idx': 1577,
#  'time': '00:10:00',
#  'Man': '红鞋子的话',
#  'content': '赤い靴なら',
#  'tBD': '红色的鞋子',
#  'tG': '红鞋子',
#  'tD': '如果是红鞋...',
#  'time_raw': 600.247}

# %%
comment_pool.time_offset
# Out:
# 600.0

# %%
curr_frame_new_comments = comment_pool.get_new_comments_before_time(601.2002741909314)

# %%
curr_frame_new_comments
# Out:
# [{'idx': 1577,
#   'time': '00:10:00',
#   'Man': '红鞋子的话',
#   'content': '赤い靴なら',
#   'tBD': '红色的鞋子',
#   'tG': '红鞋子',
#   'tD': '如果是红鞋...',
#   'time_raw': 600.247},
#  {'idx': 1578,
#   'time': '00:10:01',
#   'Man': '委员长回家不把鞋子摆好吗？',
#   'content': '委員長帰ってもクツ揃えないってマ？',
#   'tBD': '委员长回去了也没准备好吗？',
#   'tG': '主席，你说你回家不能穿鞋？',
#   'tD': '当主席回家时，他并没有准备好他的鞋子。',
#   'time_raw': 601.404},
#  {'idx': 1579,
#   'time': '00:10:01',
#   'Man': '好好地摆着 应该不会有事吧',
#   'content': 'オシャレに重ねてるから大丈夫でしょ',
#   'tBD': '因为很时尚所以没关系吧',
#   'tG': '没关系，因为它很时尚',
#   'tD': '你以一种时尚的方式将它们分层，所以它是可以的。',
#   'time_raw': 601.569},
#  {'idx': 1580,
#   'time': '00:10:01',
#   'Man': '红鞋子是恐怖故事吧',
#   'content': '赤い靴はホラーじゃん',
#   'tBD': '红色的鞋子不是恐怖的吗',
#   'tG': '红鞋很恐怖',
#   'tD': '红鞋子》是一个恐怖的故事。',
#   'time_raw': 601.818},
#  {'idx': 1581,
#   'time': '00:10:02',
#   'Man': '别啊',
#   'content': 'やめーや',
#   'tBD': '住手',
#   'tG': '停止',
#   'tD': '停止吧！',
#   'time_raw': 602.0},
#  {'idx': 1582,
#   'time': '00:10:02',
#   'Man': '那不是红鞋子吗',
#   'content': 'あかいくつじゃないのか',
#   'tBD': '不多大了',
#   'tG': '你不老吗',
#   'tD': '我以为那是红鞋。',
#   'time_raw': 602.139},
#  {'idx': 1583,
#   'time': '00:10:02',
#   'Man': '无法停止跳舞的人',
#   'content': '踊りまくるやつ',
#   'tBD': '一个劲地跳舞的家伙',
#   'tG': '跳舞的人',
#   'tD': '那个到处跳舞的人。',
#   'time_raw': 602.245},
#  {'idx': 1584,
#   'time': '00:10:03',
#   'Man': '穿着蓝色的鞋子……',
#   'content': '青い靴履いてた…',
#   'tBD': '穿着蓝色的鞋子…',
#   'tG': '我穿蓝鞋',
#   'tD': '他穿着蓝色的鞋子...',
#   'time_raw': 603.657},
#  {'idx': 1586,
#   'time': '00:10:05',
#   'Man': '超级棒啊',
#   'content': 'めっちゃいいな',
#   'tBD': '非常好啊',
#   'tG': '它是那么好',
#   'tD': '非常好。',
#   'time_raw': 605.067},
#  {'idx': 1587,
#   'time': '00:10:05',
#   'Man': '珈伦',
#   'content': 'カーレンだっけ',
#   'tBD': '卡伦来着',
#   'tG': '是凯伦',
#   'tD': '卡伦，对吗？',
#   'time_raw': 605.421},
#  {'idx': 1588,
#   'time': '00:10:05',
#   'Man': '哦哦 演出棒',
#   'content': 'ええ、演出良',
#   'tBD': '嗯，演出良',
#   'tG': '是的，演技不错',
#   'tD': '是的，好的方向',
#   'time_raw': 605.71},
#  {'idx': 1590,
#   'time': '00:10:06',
#   'Man': '童话……',
#   'content': '御伽…',
#   'tBD': '御伽…',
#   'tG': '仙女…',
#   'tD': '奥托吉 ...',
#   'time_raw': 606.937},
#  {'idx': 1591,
#   'time': '00:10:07',
#   'Man': '在说什么？',
#   'content': 'どんな話？',
#   'tBD': '什么话？',
#   'tG': '什么样的故事？',
#   'tD': '有什么故事？',
#   'time_raw': 607.782},
#  {'idx': 1592,
#   'time': '00:10:07',
#   'Man': '那个挺吓人',
#   'content': 'あれこわい',
#   'tBD': '那个可怕',
#   'tG': '害怕',
#   'tD': '这很吓人。',
#   'time_raw': 607.785},
#  {'idx': 1593,
#   'time': '00:10:08',
#   'Man': '被外国先生带走了',
#   'content': '異人さんに連れていかれる',
#   'tBD': '被外国人带去',
#   'tG': '被陌生人带走',
#   'tD': '被外星人带走了。',
#   'time_raw': 608.482},
#  {'idx': 1594,
#   'time': '00:10:09',
#   'Man': '红鞋的女孩的故事很不妙',
#   'content': '赤い靴の女の子の話はやばい',
#   'tBD': '穿着红色鞋子的女孩子的话很糟糕',
#   'tG': '红鞋少女的故事很危险',
#   'tD': '穿红鞋的女孩的故事很糟糕。',
#   'time_raw': 609.026},
#  {'idx': 1595,
#   'time': '00:10:09',
#   'Man': '像素厉害',
#   'content': 'ドットすご',
#   'tBD': '点厉害',
#   'tG': '点菅',
#   'tD': '点状虾虎鱼(Leucopsarion dumeriliensis)',
#   'time_raw': 609.054},
#  {'idx': 1596,
#   'time': '00:10:09',
#   'Man': '七草日花',
#   'content': '七草にちか...',
#   'tBD': '七草。。。',
#   'tG': '靠近七草...',
#   'tD': '七天中的七种草药...',
#   'time_raw': 609.072},
#  {'idx': 1597,
#   'time': '00:10:10',
#   'Man': '穿蓝鞋的小女孩～♪',
#   'content': '青い履いてた女の子～♪',
#   'tBD': '穿着蓝色的女孩子～♪',
#   'tG': '一个穿蓝色衣服的女孩',
#   'tD': '穿蓝色衣服的女孩~♪',
#   'time_raw': 610.71},
#  {'idx': 1598,
#   'time': '00:10:10',
#   'Man': '演出真棒',
#   'content': '演出いいねえ',
#   'tBD': '演出真好啊',
#   'tG': '我喜欢制作',
#   'tD': '方向不错。',
#   'time_raw': 610.914},
#  {'idx': 1599,
#   'time': '00:10:11',
#   'Man': '是真实的故事!',
#   'content': '実話だよぅ！',
#   'tBD': '是实话哟！',
#   'tG': '这是一个真实的故事！',
#   'tD': '真实的故事!',
#   'time_raw': 611.272},
#  {'idx': 1600,
#   'time': '00:10:11',
#   'Man': '外国先生',
#   'content': '異人さんに',
#   'tBD': '对外国人说',
#   'tG': '对陌生人',
#   'tD': '给一个外国人。',
#   'time_raw': 611.825},
#  {'idx': 1601,
#   'time': '00:10:13',
#   'Man': '心理测量者开始了',
#   'content': 'サイコメトラーはじまった',
#   'tBD': '精神病患者停止了',
#   'tG': '心理测量仪开始了',
#   'tD': '心理测量师已经开始。',
#   'time_raw': 613.098},
#  {'idx': 1602,
#   'time': '00:10:13',
#   'Man': '像是电影',
#   'content': '映画みたい',
#   'tBD': '像电影一样',
#   'tG': '像一部电影',
#   'tD': '这就像一部电影。',
#   'time_raw': 613.411},
#  {'idx': 1603,
#   'time': '00:10:13',
#   'Man': '红鞋很吓人',
#   'content': '赤い靴は怖い',
#   'tBD': '红色的鞋子很可怕',
#   'tG': '红鞋很吓人',
#   'tD': '我害怕红色的鞋子。',
#   'time_raw': 613.821},
#  {'idx': 1604,
#   'time': '00:10:16',
#   'Man': '哦？',
#   'content': 'お？',
#   'tBD': '哦？',
#   'tG': '哦？',
#   'tD': '哦？',
#   'time_raw': 616.547},
#  {'idx': 1605,
#   'time': '00:10:16',
#   'Man': '被外国先生带走了～',
#   'content': '異人さんに連れられて～',
#   'tBD': '被外国人带着～',
#   'tG': '被陌生人带走',
#   'tD': '被一个外星人带走了~。',
#   'time_raw': 616.772},
#  {'idx': 1606,
#   'time': '00:10:17',
#   'Man': '可怕',
#   'content': 'こわ',
#   'tBD': '铁皮',
#   'tG': '害怕',
#   'tD': '可怕的',
#   'time_raw': 617.306},
#  {'idx': 1607,
#   'time': '00:10:17',
#   'Man': '会这样继续推进吗',
#   'content': 'こうやって進むのかな',
#   'tBD': '这样前进吗',
#   'tG': '我想知道是不是这样',
#   'tD': '事情就是这样发展的。',
#   'time_raw': 617.45},
#  {'idx': 1608,
#   'time': '00:10:17',
#   'Man': '不安……',
#   'content': '不穏だな…',
#   'tBD': '不稳啊…',
#   'tG': '令人不安...',
#   'tD': '令人不安的是...',
#   'time_raw': 617.662},
#  {'idx': 1609,
#   'time': '00:10:18',
#   'Man': '噢噢',
#   'content': 'ほおー',
#   'tBD': '呵呵',
#   'tG': '脸颊',
#   'tD': '惊讶或赞叹的表情',
#   'time_raw': 618.335},
#  {'idx': 1610,
#   'time': '00:10:18',
#   'Man': '像素表现真美啊',
#   'content': 'ドット表現綺麗やなあ',
#   'tBD': '圆点表现很漂亮啊',
#   'tG': '圆点表情很美',
#   'tD': '美丽的点状表达。',
#   'time_raw': 618.93},
#  {'idx': 1612,
#   'time': '00:10:23',
#   'Man': '横滨的那首歌',
#   'content': '横浜のあの歌か',
#   'tBD': '横滨的那首歌',
#   'tG': '横滨的那首歌',
#   'tD': '在横滨的那首歌。',
#   'time_raw': 623.052},
#  {'idx': 1613,
#   'time': '00:10:25',
#   'Man': '有点emo',
#   'content': 'なんかエモ',
#   'tBD': '总觉得',
#   'tG': '有点情绪化',
#   'tD': '一些情绪化的东西。',
#   'time_raw': 625.416},
#  {'idx': 1614,
#   'time': '00:10:25',
#   'Man': '踩面包地那个吗',
#   'content': 'パン踏むやつか',
#   'tBD': '踩着面包的家伙',
#   'tG': '面包机',
#   'tD': '烙印面包。',
#   'time_raw': 625.955},
#  {'idx': 1615,
#   'time': '00:10:26',
#   'Man': '害怕',
#   'content': 'こわい',
#   'tBD': '可怕的',
#   'tG': '害怕',
#   'tD': '怕',
#   'time_raw': 626.012},
#  {'idx': 1616,
#   'time': '00:10:26',
#   'Man': '害怕害怕',
#   'content': 'こわいこわい',
#   'tBD': '可怕的',
#   'tG': '可怕的',
#   'tD': '(害怕)僵硬',
#   'time_raw': 626.282},
#  {'idx': 1617,
#   'time': '00:10:26',
#   'Man': '从这个世界byebye？',
#   'content': 'この世界からバイバイ？',
#   'tBD': '从这个世界说再见？',
#   'tG': '告别这个世界？',
#   'tD': '从这个世界告别？',
#   'time_raw': 626.341},
#  {'idx': 1618,
#   'time': '00:10:27',
#   'Man': '可怕',
#   'content': 'こわい',
#   'tBD': '可怕的',
#   'tG': '害怕',
#   'tD': '怕',
#   'time_raw': 627.829},
#  {'idx': 1619,
#   'time': '00:10:28',
#   'Man': '可怕',
#   'content': 'こっわ',
#   'tBD': '软骨',
#   'tG': '害怕',
#   'tD': '可怕的',
#   'time_raw': 628.516},
#  {'idx': 1620,
#   'time': '00:10:29',
#   'Man': '不安',
#   'content': '不穏',
#   'tBD': '不稳',
#   'tG': '动荡',
#   'tD': '动乱',
#   'time_raw': 629.294},
#  {'idx': 1621,
#   'time': '00:10:29',
#   'Man': '突然不安',
#   'content': 'いきなり不穏な',
#   'tBD': '突然不稳的',
#   'tG': '突然打扰',
#   'tD': '突然感到不安。',
#   'time_raw': 629.294},
#  {'idx': 1623,
#   'time': '00:10:29',
#   'Man': '棒 超棒',
#   'content': '良い\u3000めっちゃ良い',
#   'tBD': '非常好',
#   'tG': '好，很好',
#   'tD': '很好，非常好。',
#   'time_raw': 629.455},
#  {'idx': 1624,
#   'time': '00:10:29',
#   'Man': '逃出去',
#   'content': '抜け出す',
#   'tBD': '溜走',
#   'tG': '爆发',
#   'tD': '溜走',
#   'time_raw': 629.483},
#  {'idx': 1625,
#   'time': '00:10:30',
#   'Man': '！',
#   'content': '！',
#   'tBD': '！',
#   'tG': '！',
#   'tD': '!!!',
#   'time_raw': 630.615},
#  {'idx': 1626,
#   'time': '00:10:31',
#   'Man': '不行啊',
#   'content': 'だめです',
#   'tBD': '不行，不行',
#   'tG': '不要那样做',
#   'tD': '不，你不能。',
#   'time_raw': 631.391},
#  {'idx': 1627,
#   'time': '00:10:31',
#   'Man': '让我想起了DAOKO的歌',
#   'content': 'DAOKOの曲思い出す',
#   'tBD': '想起DAOKO的曲子',
#   'tG': '让我想起了DAOKO的歌',
#   'tD': '让我想起了DAOKO的一首歌。',
#   'time_raw': 631.865},
#  {'idx': 1628,
#   'time': '00:10:32',
#   'Man': '是恐怖游戏吧',
#   'content': 'ホラーなん',
#   'tBD': '恐怖啊',
#   'tG': '多么恐怖',
#   'tD': '恐怖故事',
#   'time_raw': 632.51},
#  {'idx': 1629,
#   'time': '00:10:32',
#   'Man': '♪',
#   'content': '♪',
#   'tBD': '♪',
#   'tG': '♪',
#   'tD': '♪',
#   'time_raw': 632.51},
#  {'idx': 1630,
#   'time': '00:10:32',
#   'Man': '是恐怖游戏吗？',
#   'content': 'ホラーゲーですか？',
#   'tBD': '是恐怖游戏吗？',
#   'tG': '你是恐怖游戏吗？',
#   'tD': '这是一个恐怖游戏吗？',
#   'time_raw': 632.543},
#  {'idx': 1631,
#   'time': '00:10:32',
#   'Man': '害怕',
#   'content': 'こわい',
#   'tBD': '可怕的',
#   'tG': '害怕',
#   'tD': '怕',
#   'time_raw': 632.548},
#  {'idx': 1632,
#   'time': '00:10:34',
#   'Man': '突然超展开',
#   'content': '急にくるやん',
#   'tBD': '突然来了',
#   'tG': '突然来',
#   'tD': '你突然来了。',
#   'time_raw': 634.003},
#  {'idx': 1633,
#   'time': '00:10:35',
#   'Man': '物理上的？',
#   'content': '物理的に？',
#   'tBD': '物理上？',
#   'tG': '身体上？',
#   'tD': '身体？',
#   'time_raw': 635.366},
#  {'idx': 1634,
#   'time': '00:10:36',
#   'Man': '演出真棒',
#   'content': '演出いいな',
#   'tBD': '演出真好啊',
#   'tG': '生产很好',
#   'tD': '我喜欢这个方向。',
#   'time_raw': 636.659},
#  {'idx': 1635,
#   'time': '00:10:36',
#   'Man': '噫噫',
#   'content': 'ひえ',
#   'tBD': '比价',
#   'tG': '稗子',
#   'tD': '寒冷的暴露',
#   'time_raw': 636.845},
#  {'idx': 1636,
#   'time': '00:10:37',
#   'Man': '真好啊',
#   'content': 'いいねえ',
#   'tBD': '好啊',
#   'tG': '好的',
#   'tD': '这很好。',
#   'time_raw': 637.235},
#  {'idx': 1637,
#   'time': '00:10:37',
#   'Man': '感应少女',
#   'content': 'サイコメトラー女',
#   'tBD': '神经病女',
#   'tG': '心理学家的女人',
#   'tD': '女心理咨询师',
#   'time_raw': 637.348},
#  {'idx': 1638,
#   'time': '00:10:38',
#   'Man': '像是恐怖游戏',
#   'content': 'ホラーっぽいな',
#   'tBD': '好恐怖啊',
#   'tG': '恐怖',
#   'tD': '听起来像是一个恐怖的故事。',
#   'time_raw': 638.364},
#  {'idx': 1639,
#   'time': '00:10:38',
#   'Man': '唔……头',
#   'content': 'うっ頭が',
#   'tBD': '黑头',
#   'tG': '拥塞',
#   'tD': '我的头',
#   'time_raw': 638.465},
#  {'idx': 1640,
#   'time': '00:10:38',
#   'Man': '不能会想起的东西是？',
#   'content': '思い出しちゃいけないものか？',
#   'tBD': '不可以回想起来吗？',
#   'tG': '是不是你记不得了？',
#   'tD': '我不应该记住的东西？',
#   'time_raw': 638.712},
#  {'idx': 1641,
#   'time': '00:10:39',
#   'Man': '感应少年吧',
#   'content': 'サイコメトラーか',
#   'tBD': '倍半化',
#   'tG': '是心理测量师吗？',
#   'tD': '心理测量师。',
#   'time_raw': 639.853},
#  {'idx': 1642,
#   'time': '00:10:40',
#   'Man': '恐怖游戏？',
#   'content': 'ホラゲ？',
#   'tBD': '霍拉格？',
#   'tG': '霍拉格？',
#   'tD': '浩乐？',
#   'time_raw': 640.358},
#  {'idx': 1643,
#   'time': '00:10:40',
#   'Man': '！',
#   'content': '！',
#   'tBD': '！',
#   'tG': '！',
#   'tD': '!!!',
#   'time_raw': 640.571},
#  {'idx': 1644,
#   'time': '00:10:40',
#   'Man': '不要啊中二期的我',
#   'content': '中二の時の俺やめろ',
#   'tBD': '初中二年级的我',
#   'tG': '在我上中学的时候阻止我',
#   'tD': '我在八年级的时候，停下来。',
#   'time_raw': 640.834},
#  {'idx': 1645,
#   'time': '00:10:41',
#   'Man': '现在还什么都不清楚',
#   'content': '今のとこ何もわからんな',
#   'tBD': '现在什么都不懂',
#   'tG': '我现在什么都不知道',
#   'tD': '到目前为止，我们对它一无所知。',
#   'time_raw': 641.494},
#  {'idx': 1646,
#   'time': '00:10:41',
#   'Man': '没问题吗',
#   'content': 'いいか？',
#   'tBD': '可以吗？',
#   'tG': '好的？',
#   'tD': '准备好了吗？',
#   'time_raw': 641.903},
#  {'idx': 1647,
#   'time': '00:10:42',
#   'Man': '令人不安',
#   'content': '不穏ね',
#   'tBD': '不稳啊',
#   'tG': '令人不安',
#   'tD': '这很令人不安。',
#   'time_raw': 642.328},
#  {'idx': 1648,
#   'time': '00:10:42',
#   'Man': '可以吗~',
#   'content': 'いいすか～？',
#   'tBD': '可以吗？',
#   'tG': '你确定~？',
#   'tD': '我可以吗？',
#   'time_raw': 642.436},
#  {'idx': 1649,
#   'time': '00:10:42',
#   'Man': '宿醉？',
#   'content': '二日酔いかな？',
#   'tBD': '宿醉吗？',
#   'tG': '你宿醉吗？',
#   'tD': '宿醉？',
#   'time_raw': 642.736},
#  {'idx': 1651,
#   'time': '00:10:42',
#   'Man': '激动激动',
#   'content': 'ワクワクしてきた',
#   'tBD': '我很兴奋',
#   'tG': '我太激动了',
#   'tD': '我开始兴奋了。',
#   'time_raw': 642.816},
#  {'idx': 1652,
#   'time': '00:10:42',
#   'Man': '哦哦……',
#   'content': 'おお…',
#   'tBD': '哦…',
#   'tG': '哦…',
#   'tD': '哦...',
#   'time_raw': 642.935},
#  {'idx': 1653,
#   'time': '00:10:42',
#   'Man': '好帅~',
#   'content': 'かっこいい～',
#   'tBD': '好帅~',
#   'tG': '酷~',
#   'tD': '酷~。',
#   'time_raw': 642.971},
#  {'idx': 1654,
#   'time': '00:10:43',
#   'Man': '好像很喜欢啊hhh',
#   'content': 'すきそうやなぁｗ',
#   'tBD': '好像很喜欢啊w',
#   'tG': '看起来不错w',
#   'tD': '你看起来很喜欢这样。',
#   'time_raw': 643.482},
#  {'idx': 1655,
#   'time': '00:10:43',
#   'Man': '真棒',
#   'content': 'いいね',
#   'tBD': '不错啊',
#   'tG': '多好',
#   'tD': '很好。',
#   'time_raw': 643.482},
#  {'idx': 1656,
#   'time': '00:10:44',
#   'Man': '真好',
#   'content': 'いいね',
#   'tBD': '不错啊',
#   'tG': '多好',
#   'tD': '很好。',
#   'time_raw': 644.295},
#  {'idx': 1657,
#   'time': '00:10:44',
#   'Man': '喜欢演出',
#   'content': '演出すき',
#   'tBD': '喜欢演出',
#   'tG': '喜欢导演',
#   'tD': '爱好执导',
#   'time_raw': 644.931},
#  {'idx': 1658,
#   'time': '00:10:45',
#   'Man': '太棒了！',
#   'content': 'いいねえ！',
#   'tBD': '好啊！',
#   'tG': '好的！',
#   'tD': '好样的!',
#   'time_raw': 645.646},
#  {'idx': 1659,
#   'time': '00:10:45',
#   'Man': '我喜欢这个...',
#   'content': 'こういうのいいな…',
#   'tBD': '这样好啊…',
#   'tG': '我喜欢这个...',
#   'tD': '我喜欢这种事情...',
#   'time_raw': 645.835},
#  {'idx': 1660,
#   'time': '00:10:46',
#   'Man': '什么情况',
#   'content': '何がよ',
#   'tBD': '什么呀',
#   'tG': '这是怎么回事',
#   'tD': '这他妈的是什么？',
#   'time_raw': 646.496},
#  {'idx': 1661,
#   'time': '00:10:47',
#   'Man': '被外国先生带走了',
#   'content': 'ニンジンさんに連れられて',
#   'tBD': '被胡萝卜先生带着',
#   'tG': '胡萝卜先生陪同',
#   'tD': '由胡萝卜先生拍摄。',
#   'time_raw': 647.733},
#  {'idx': 1662,
#   'time': '00:10:48',
#   'Man': '演出真棒啊',
#   'content': '演出良いな',
#   'tBD': '演出很好啊',
#   'tG': '生产很好',
#   'tD': '好的方向。',
#   'time_raw': 648.563},
#  {'idx': 1663,
#   'time': '00:10:48',
#   'Man': '世界观好厉害',
#   'content': 'すごい世界観だ',
#   'tBD': '很厉害的世界观',
#   'tG': '惊人的世界观',
#   'tD': '这是一个伟大的世界观。',
#   'time_raw': 648.882},
#  {'idx': 1664,
#   'time': '00:10:49',
#   'Man': '这是195吗',
#   'content': 'これ195かな',
#   'tBD': '这是195吧',
#   'tG': '我想知道这是不是195',
#   'tD': '这是195号吗？',
#   'time_raw': 649.865},
#  {'idx': 1665,
#   'time': '00:10:49',
#   'Man': '故事展开了啊',
#   'content': '盛り上がってきたな',
#   'tBD': '气氛很热烈啊',
#   'tG': '我越来越兴奋',
#   'tD': '越来越令人兴奋了。',
#   'time_raw': 649.891},
#  {'idx': 1666,
#   'time': '00:10:50',
#   'Man': '世界观超赞',
#   'content': '世界観やばい',
#   'tBD': '世界观不得了',
#   'tG': '世界观很危险',
#   'tD': '世界观不好。',
#   'time_raw': 650.556},
#  {'idx': 1667,
#   'time': '00:10:50',
#   'Man': '好棒的像素画',
#   'content': 'ドットすごいな',
#   'tBD': '圆点好厉害啊',
#   'tG': '点是惊人的',
#   'tD': '小不点很了不起。',
#   'time_raw': 650.956},
#  {'idx': 1668,
#   'time': '00:10:51',
#   'Man': '这家伙 直接在脑内！！',
#   'content': 'こいつ直接脳内に！！',
#   'tBD': '这家伙直接进入脑内！！',
#   'tG': '这家伙直接在我脑子里！ ！',
#   'tD': '这家伙直接进入了大脑!',
#   'time_raw': 651.098},
#  {'idx': 1669,
#   'time': '00:10:53',
#   'Man': '不要解析啊',
#   'content': '解析するなよｗ',
#   'tBD': '不要解析哦w',
#   'tG': '不分析',
#   'tD': '不要分析它。',
#   'time_raw': 653.11},
#  {'idx': 1670,
#   'time': '00:10:54',
#   'Man': '刚好对得上委员长的XP',
#   'content': '委員長の性癖とバチこりあってると思う',
#   'tBD': '我觉得和委员长的脾气有关系',
#   'tG': '我认为主席的倾向和粘性',
#   'tD': '我认为这与专员的癖好是大黄蜂式的匹配。',
#   'time_raw': 654.59},
#  {'idx': 1671,
#   'time': '00:10:54',
#   'Man': '有那个欺诈广告游戏的感觉',
#   'content': '例の詐欺広告ゲームっぽさあった',
#   'tBD': '有那个欺诈广告游戏的感觉',
#   'tG': '这就像欺诈性广告游戏',
#   'tD': '这就像例子中的诈骗广告游戏。',
#   'time_raw': 654.734},
#  {'idx': 1672,
#   'time': '00:10:55',
#   'Man': '能够传送到大脑已经很危险了',
#   'content': '脳内に送信できるのがもうヤバイ',
#   'tBD': '能发送到脑内已经很糟糕了',
#   'tG': '能够传送到大脑已经很危险了',
#   'tD': '这已经很糟糕了，它可以传到大脑中。',
#   'time_raw': 655.206},
#  {'idx': 1673,
#   'time': '00:10:55',
#   'Man': '你……难道说……',
#   'content': 'お前…もしかして…',
#   'tBD': '你…难道…',
#   'tG': '你可能会...',
#   'tD': '你...你可能是...',
#   'time_raw': 655.527},
#  {'idx': 1674,
#   'time': '00:10:55',
#   'Man': '这游戏好有趣',
#   'content': 'このゲームおもしれーよな',
#   'tBD': '这个游戏很有趣吧',
#   'tG': '这个游戏很有趣',
#   'tD': '这个游戏很有趣，不是吗？',
#   'time_raw': 655.528},
#  {'idx': 1675,
#   'time': '00:10:57',
#   'Man': '什么样的解析？',
#   'content': 'なんの解析だよ',
#   'tBD': '什么分析啊',
#   'tG': '什么样的分析',
#   'tD': '什么分析？',
#   'time_raw': 657.962},
#  {'idx': 1676,
#   'time': '00:10:58',
#   'Man': '委员长喜欢的世界观',
#   'content': '委員長の好きそうな世界観よね',
#   'tBD': '委员长喜欢的世界观吧',
#   'tG': '这是主席似乎喜欢的世界观，不是吗？',
#   'tD': '这是主席喜欢的那种世界观。',
#   'time_raw': 658.579},
#  {'idx': 1677,
#   'time': '00:10:59',
#   'Man': '电脑被黑了！',
#   'content': '電脳をジャックされた！',
#   'tBD': '电脑被劫持了！',
#   'tG': '大脑被绞死了！',
#   'tD': '他们劫持了我们的电话!',
#   'time_raw': 659.282},
#  {'idx': 1678,
#   'time': '00:11:00',
#   'Man': '（请来一份全家炸鸡）',
#   'content': '（ファミチキください）',
#   'tBD': '（请给我全家票）',
#   'tG': '（请Famichiki）',
#   'tD': '(Famichiki please)。',
#   'time_raw': 660.007},
#  {'idx': 1679,
#   'time': '00:11:01',
#   'Man': '而且可以控制脑电波',
#   'content': 'しかも脳波コントロールできる',
#   'tBD': '而且可以控制脑波',
#   'tG': '你可以控制你的脑电波',
#   'tD': '而且你可以控制脑电波。',
#   'time_raw': 661.417},
#  {'idx': 1680,
#   'time': '00:11:01',
#   'Man': '（请来一份全家炸鸡）',
#   'content': '（ファミチキください）',
#   'tBD': '（请给我全家票）',
#   'tG': '（请Famichiki）',
#   'tD': '(Famichiki please)。',
#   'time_raw': 661.967},
#  {'idx': 1681,
#   'time': '00:11:03',
#   'Man': '全家炸鸡自助啊',
#   'content': 'ファミチキ買い放題じゃん',
#   'tBD': '全家都可以随便买嘛',
#   'tG': '任你吃的Famichiki',
#   'tD': '你可以买到你想要的所有法米奇!',
#   'time_raw': 663.394},
#  {'idx': 1682,
#   'time': '00:11:04',
#   'Man': '这家伙 直接在脑内……！',
#   'content': 'こいつ直接脳内に…！',
#   'tBD': '这家伙直接进入脑内…！',
#   'tG': '这家伙直接在我的脑海里……！',
#   'tD': '它直接在他的大脑中!',
#   'time_raw': 664.114},
#  {'idx': 1684,
#   'time': '00:11:04',
#   'Man': '植物人？',
#   'content': '植物人間？',
#   'tBD': '植物人？',
#   'tG': '植物人？',
#   'tD': '一个植物人？',
#   'time_raw': 664.699},
#  {'idx': 1685,
#   'time': '00:11:04',
#   'Man': '有能',
#   'content': '有能',
#   'tBD': '有能力',
#   'tG': '高效的',
#   'tD': '有能力',
#   'time_raw': 664.827},
#  {'idx': 1686,
#   'time': '00:11:05',
#   'Man': '全家炸鸡hhhh',
#   'content': 'ファミチキｗｗ',
#   'tBD': 'Famichiki ww',
#   'tG': '家庭万维网',
#   'tD': 'Famichiki WW.',
#   'time_raw': 665.009},
#  {'idx': 1687,
#   'time': '00:11:05',
#   'Man': '请来一份全家炸鸡',
#   'content': 'ファミチキください',
#   'tBD': '请给我传真',
#   'tG': '请Famichiki',
#   'tD': '法米奇，请。',
#   'time_raw': 665.23},
#  {'idx': 1688,
#   'time': '00:11:05',
#   'Man': '心理测量发动了',
#   'content': 'サイコメトリー発動ね',
#   'tBD': '赛米特里发动了',
#   'tG': '激活心理测量',
#   'tD': '心理测量的激活。',
#   'time_raw': 665.751},
#  {'idx': 1689,
#   'time': '00:11:05',
#   'Man': '鸡块也来一份',
#   'content': 'Lチキもください',
#   'tBD': '也请给我蛋糕',
#   'tG': 'L chiki 请',
#   'tD': '我也要一个L-tiki，谢谢。',
#   'time_raw': 665.777},
#  {'idx': 1690,
#   'time': '00:11:05',
#   'Man': '（怎可能）',
#   'content': '(なわけ)',
#   'tBD': '（为什么）',
#   'tG': '（为什么）',
#   'tD': '(Nawazake)。',
#   'time_raw': 665.806},
#  {'idx': 1691,
#   'time': '00:11:06',
#   'Man': '刚才的是虚拟空间吗',
#   'content': 'さっきのが仮想空間なのかな',
#   'tBD': '刚才的是虚拟空间吗',
#   'tG': '我想知道那是不是一个虚拟空间',
#   'tD': '我不知道这是否是早期的虚拟空间。',
#   'time_raw': 666.961},
#  {'idx': 1692,
#   'time': '00:11:07',
#   'Man': '委员长不管什么时候大脑总是乱的吧',
#   'content': '委員長は何時も脳は乱れてるだろ',
#   'tBD': '委员长总是大脑混乱吧',
#   'tG': '董事长脑子总是乱',
#   'tD': '主席的脑子总是乱糟糟的，不是吗？',
#   'time_raw': 667.011},
#  {'idx': 1693,
#   'time': '00:11:07',
#   'Man': '全家炸鸡草',
#   'content': 'ファミチキ草',
#   'tBD': '野草',
#   'tG': '家常草',
#   'tD': '含羞草',
#   'time_raw': 667.478},
#  {'idx': 1694,
#   'time': '00:11:07',
#   'Man': '脑电波直连',
#   'content': '脳波直結',
#   'tBD': '脑电波直接连接',
#   'tG': '脑电图直连',
#   'tD': '直接连接到脑电波',
#   'time_raw': 667.748},
#  {'idx': 1695,
#   'time': '00:11:08',
#   'Man': '虚拟世界？',
#   'content': 'バーチャルの世界？',
#   'tBD': '虚拟世界？',
#   'tG': '虚拟世界？',
#   'tD': '一个虚拟的世界？',
#   'time_raw': 668.272},
#  {'idx': 1696,
#   'time': '00:11:08',
#   'Man': '草',
#   'content': '草',
#   'tBD': '草本',
#   'tG': '草',
#   'tD': '草',
#   'time_raw': 668.486},
#  {'idx': 1697,
#   'time': '00:11:08',
#   'Man': '（请来一份全家炸鸡）',
#   'content': '(ファミチキください……)',
#   'tBD': '（请给我全家……）',
#   'tG': '（请Famichiki...）',
#   'tD': '(Famichiki please, ......)',
#   'time_raw': 668.696},
#  {'idx': 1698,
#   'time': '00:11:08',
#   'Man': '（这里是罗森）',
#   'content': '（ここローソンです）',
#   'tBD': '（这里是罗森）',
#   'tG': '（这是劳森）',
#   'tD': '(这里是劳森。)',
#   'time_raw': 668.96},
#  {'idx': 1699,
#   'time': '00:11:09',
#   'Man': '像素的表现真的很赞啊',
#   'content': 'ドット表現ほんとにすごいよなあ',
#   'tBD': '圆点表现真的很厉害啊',
#   'tG': '点的表达真的很神奇',
#   'tD': '点点的表情真的很神奇。',
#   'time_raw': 669.29},
#  {'idx': 1700,
#   'time': '00:11:10',
#   'Man': '远古neta持续发生',
#   'content': '古のネタが続々と',
#   'tBD': '古老的段子不断',
#   'tG': '一系列老故事',
#   'tD': '很多老故事。',
#   'time_raw': 670.285},
#  {'idx': 1701,
#   'time': '00:11:10',
#   'Man': '「请来一份全家炸鸡……」',
#   'content': '「ファミチキください‥」',
#   'tBD': '“请给我全家。”',
#   'tG': '“法米奇请……”',
#   'tD': '法米奇，请...',
#   'time_raw': 670.424},
#  {'idx': 1703,
#   'time': '00:11:12',
#   'Man': '万能信号灯',
#   'content': '信号機万能だぜ',
#   'tBD': '信号机是万能的',
#   'tG': '交通灯是完美的',
#   'tD': '交通灯是全能的，伙计。',
#   'time_raw': 672.005},
#  {'idx': 1704,
#   'time': '00:11:12',
#   'Man': '噢噢',
#   'content': 'おお',
#   'tBD': '大的',
#   'tG': '哦',
#   'tD': '哦!',
#   'time_raw': 672.013},
#  {'idx': 1705,
#   'time': '00:11:12',
#   'Man': '能从脑电波解析出画面',
#   'content': '脳波から画像解析とは',
#   'tBD': '脑波ー解析',
#   'tG': '什么是脑电图的图像分析？',
#   'tD': '什么是脑电图到图像分析？',
#   'time_raw': 672.743},
#  {'idx': 1706,
#   'time': '00:11:14',
#   'Man': '这家伙……直接对脑袋……',
#   'content': 'こいつ…脳に直接ッ…',
#   'tBD': '这家伙……直接进入大脑…',
#   'tG': '这家伙……直接入脑……',
#   'tD': '这东西......直达大脑......。',
#   'time_raw': 674.271},
#  {'idx': 1707,
#   'time': '00:11:14',
#   'Man': '（请来一份全家炸鸡）',
#   'content': '（ファミチキください）',
#   'tBD': '（请给我全家票）',
#   'tG': '（请Famichiki）',
#   'tD': '(Famichiki please)。',
#   'time_raw': 674.672},
#  {'idx': 1708,
#   'time': '00:11:14',
#   'Man': '噢噢',
#   'content': 'おお',
#   'tBD': '大的',
#   'tG': '哦',
#   'tD': '哦!',
#   'time_raw': 674.72},
#  {'idx': 1709,
#   'time': '00:11:15',
#   'Man': '老师？',
#   'content': '先生？',
#   'tBD': '老师？',
#   'tG': '先生？',
#   'tD': '老师？',
#   'time_raw': 675.031},
#  {'idx': 1710,
#   'time': '00:11:15',
#   'Man': '你不擅长人工智能吗？',
#   'content': 'AIの粋肥えてない？',
#   'tBD': 'AI不漂亮吗？',
#   'tG': '你不擅长人工智能吗？',
#   'tD': '人工智能还不够别致吗？',
#   'time_raw': 675.415},
#  {'idx': 1711,
#   'time': '00:11:16',
#   'Man': '哦呀',
#   'content': 'おや',
#   'tBD': '主子',
#   'tG': '晚安',
#   'tD': '父母',
#   'time_raw': 676.666},
#  {'idx': 1712,
#   'time': '00:11:17',
#   'Man': 'Eji...',
#   'content': 'エイジ・・・',
#   'tBD': '年龄',
#   'tG': '年龄...',
#   'tD': '年龄...',
#   'time_raw': 677.418},
#  {'idx': 1713,
#   'time': '00:11:17',
#   'Man': '常见的激寒推特不要啊',
#   'content': 'よくある激寒ツイートやめろ',
#   'tBD': '常见的激寒推特',
#   'tG': '停止通常的极端冷推文',
#   'tD': '停止经常非常冷的推文。',
#   'time_raw': 677.673},
#  {'idx': 1714,
#   'time': '00:11:17',
#   'Man': '哦哦！',
#   'content': 'おお！',
#   'tBD': '哦！',
#   'tG': '哦！',
#   'tD': '哦!',
#   'time_raw': 677.751},
#  {'idx': 1715,
#   'time': '00:11:17',
#   'Man': '好怀念',
#   'content': '懐かしい',
#   'tBD': '令人怀念',
#   'tG': '怀旧的',
#   'tD': '亲爱的',
#   'time_raw': 677.82},
#  {'idx': 1716,
#   'time': '00:11:18',
#   'Man': '还能解析出心理图像啊',
#   'content': '心理映像出力できんのかよ',
#   'tBD': '你能把心理影像输出出来吗',
#   'tG': '是否可以输出心理图像？',
#   'tD': '你能输出心理学图像吗？',
#   'time_raw': 678.261},
#  {'idx': 1717,
#   'time': '00:11:18',
#   'Man': 'EIJI!?',
#   'content': 'EIJI!?',
#   'tBD': 'EIJI!?',
#   'tG': '英治！？',
#   'tD': 'EIJI!',
#   'time_raw': 678.293},
#  {'idx': 1718,
#   'time': '00:11:18',
#   'Man': '便量测量者',
#   'content': 'うんこメトラー',
#   'tBD': '大便测定器',
#   'tG': '便便者',
#   'tD': '大便计量器',
#   'time_raw': 678.329},
#  {'idx': 1719,
#   'time': '00:11:18',
#   'Man': '好老的梗',
#   'content': 'ふっるｗ',
#   'tBD': '甩了w',
#   'tG': '哇',
#   'tD': '飓风湿巾',
#   'time_raw': 678.413},
#  {'idx': 1720,
#   'time': '00:11:18',
#   'Man': '怀念',
#   'content': 'なっつ',
#   'tBD': '压印',
#   'tG': '夏',
#   'tD': '印刷卡片的速度，使印刷的总份数小于或等于印刷的数量',
#   'time_raw': 678.575},
#  {'idx': 1721,
#   'time': '00:11:18',
#   'Man': '好怀念',
#   'content': 'なつかしい',
#   'tBD': '怀念，眷念',
#   'tG': '怀旧',
#   'tD': '错过了',
#   'time_raw': 678.707},
#  {'idx': 1722,
#   'time': '00:11:18',
#   'Man': '很老了啊',
#   'content': '古いんよ',
#   'tBD': '是旧的',
#   'tG': '它很旧',
#   'tD': '它是旧的。',
#   'time_raw': 678.983},
#  {'idx': 1723,
#   'time': '00:11:19',
#   'Man': '过去的影像？',
#   'content': '過去の映像？',
#   'tBD': '过去的影像？',
#   'tG': '过去的镜头？',
#   'tD': '过去的镜头？',
#   'time_raw': 679.501},
#  {'idx': 1724,
#   'time': '00:11:20',
#   'Man': '好怀念！',
#   'content': 'なつかし！',
#   'tBD': '怀念！',
#   'tG': '怀旧！',
#   'tD': '怀旧之情!',
#   'time_raw': 680.218},
#  {'idx': 1725,
#   'time': '00:11:20',
#   'Man': '噢噢',
#   'content': 'おお',
#   'tBD': '大的',
#   'tG': '哦',
#   'tD': '哦!',
#   'time_raw': 680.535},
#  {'idx': 1726,
#   'time': '00:11:20',
#   'Man': '鞋子的记忆？',
#   'content': 'くつの記憶？',
#   'tBD': '鞋子的记忆？',
#   'tG': '鞋子的回忆？',
#   'tD': '记忆中的鞋子？',
#   'time_raw': 680.809},
#  {'idx': 1727,
#   'time': '00:11:21',
#   'Man': '有点像静凛',
#   'content': 'しずりんっぽいさある',
#   'tBD': '有点无聊',
#   'tG': '有像 Shizurin 这样的东西',
#   'tD': '滴水成河的新鲜蔬菜',
#   'time_raw': 681.118},
#  {'idx': 1728,
#   'time': '00:11:21',
#   'Man': '感应少年Eiji',
#   'content': 'サイコメトラーエイジｗ',
#   'tBD': '精神测量者时代w',
#   'tG': '心理测量师年龄 w',
#   'tD': 'Psychometra Age W.',
#   'time_raw': 681.682},
#  {'idx': 1729,
#   'time': '00:11:21',
#   'Man': '怀念',
#   'content': 'なっつ',
#   'tBD': '压印',
#   'tG': '夏',
#   'tD': '印刷卡片的速度，使印刷的总份数小于或等于印刷的数量',
#   'time_raw': 681.758},
#  {'idx': 1730,
#   'time': '00:11:22',
#   'Man': '好怀念啊草',
#   'content': '懐かしくて草',
#   'tBD': '怀念的草',
#   'tG': '怀旧草',
#   'tD': '我非常想念它。',
#   'time_raw': 682.498},
#  {'idx': 1731,
#   'time': '00:11:22',
#   'Man': 'Eji好怀念',
#   'content': 'エイジなっつ',
#   'tBD': '年龄冲突',
#   'tG': '年龄纳兹',
#   'tD': '老化过程',
#   'time_raw': 682.57},
#  {'idx': 1732,
#   'time': '00:11:23',
#   'Man': '松冈君！ ?',
#   'content': '松岡くん！？',
#   'tBD': '松冈君！？',
#   'tG': '松冈君！ ?',
#   'tD': '松冈君！',
#   'time_raw': 683.299},
#  {'idx': 1733,
#   'time': '00:11:23',
#   'Man': '感应少女MITO',
#   'content': 'サイコメトラーMITO',
#   'tBD': '精神测量器MITO',
#   'tG': '心理测量仪 MITO',
#   'tD': '心理测量仪MITO',
#   'time_raw': 683.457},
#  {'idx': 1734,
#   'time': '00:11:24',
#   'Man': '真不错',
#   'content': 'いいねえ！',
#   'tBD': '好啊！',
#   'tG': '好的！',
#   'tD': '好样的!',
#   'time_raw': 684.434},
#  {'idx': 1735,
#   'time': '00:11:24',
#   'Man': '？',
#   'content': '？',
#   'tBD': '？',
#   'tG': '？',
#   'tD': '?',
#   'time_raw': 684.681},
#  {'idx': 1736,
#   'time': '00:11:24',
#   'Man': '就知道你会这么说',
#   'content': '言うと思ったw',
#   'tBD': '我以为你会说',
#   'tG': '我以为我会说',
#   'tD': '我以为你会这么说。',
#   'time_raw': 684.842},
#  {'idx': 1737,
#   'time': '00:11:25',
#   'Man': '还是老梗',
#   'content': 'また古い',
#   'tBD': '又旧了',
#   'tG': '又老了',
#   'tD': '也是旧的。',
#   'time_raw': 685.005},
#  {'idx': 1738,
#   'time': '00:11:25',
#   'Man': '（谢谢···）',
#   'content': '（サンクス・・・）',
#   'tBD': '（桑克斯・・・）',
#   'tG': '（谢谢···）',
#   'tD': '(谢谢...)',
#   'time_raw': 685.165},
#  {'idx': 1739,
#   'time': '00:11:25',
#   'Man': '怀念',
#   'content': 'なっつ',
#   'tBD': '压印',
#   'tG': '夏',
#   'tD': '印刷卡片的速度，使印刷的总份数小于或等于印刷的数量',
#   'time_raw': 685.236},
#  {'idx': 1740,
#   'time': '00:11:25',
#   'Man': '噢噢',
#   'content': 'おお',
#   'tBD': '大的',
#   'tG': '哦',
#   'tD': '哦!',
#   'time_raw': 685.281},
#  {'idx': 1741,
#   'time': '00:11:26',
#   'Man': '大便少年Eiji！？',
#   'content': 'ウンコメトラーEIJI！？',
#   'tBD': '大便测量器EIJI！？',
#   'tG': 'Uncomettor EIJI！ ?',
#   'tD': 'EIJI，大便测量仪!',
#   'time_raw': 686.116},
#  {'idx': 1742,
#   'time': '00:11:26',
#   'Man': '噢哦——',
#   'content': 'ほおー',
#   'tBD': '呵呵',
#   'tG': '脸颊',
#   'tD': '惊讶或赞叹的表情',
#   'time_raw': 686.679},
#  {'idx': 1743,
#   'time': '00:11:26',
#   'Man': '立刻能想到感应少年好厉害',
#   'content': 'サイコメトラーが即座に出るのすこ',
#   'tBD': '精神病患者马上就出来了',
#   'tG': '心理测量师会立即出现',
#   'tD': '我喜欢心理测量师的即时性。',
#   'time_raw': 686.925},
#  {'idx': 1744,
#   'time': '00:11:27',
#   'Man': '好怀念Eiji',
#   'content': 'Eijiはなついんよ',
#   'tBD': '我很怀念Eiji',
#   'tG': '英治是夏天',
#   'tD': 'Eiji是一个好朋友。',
#   'time_raw': 687.183},
#  {'idx': 1745,
#   'time': '00:11:27',
#   'Man': '怀念',
#   'content': 'なっつ',
#   'tBD': '压印',
#   'tG': '夏',
#   'tD': '印刷卡片的速度，使印刷的总份数小于或等于印刷的数量',
#   'time_raw': 687.799},
#  {'idx': 1746,
#   'time': '00:11:28',
#   'Man': 'JK知道感应少年Eiji？',
#   'content': 'JKがサイコメトラーエイジを知っているだと？',
#   'tBD': 'JK知道精神病患者吗？',
#   'tG': 'JK 知道 Psychometler 年龄吗？',
#   'tD': 'JK知道Psychometra时代吗？',
#   'time_raw': 688.092},
#  {'idx': 1747,
#   'time': '00:11:28',
#   'Man': '是松冈',
#   'content': '松岡だっけ',
#   'tBD': '是松冈吧',
#   'tG': '是松冈',
#   'tD': '松冈，对吗？',
#   'time_raw': 688.951},
#  {'idx': 1748,
#   'time': '00:11:29',
#   'Man': '感应少年Eiji是什么？',
#   'content': 'サイコメトラーエイジって何？',
#   'tBD': '什么是精神病？',
#   'tG': '什么是心理测量者年龄？',
#   'tD': '什么是心理测量年龄？',
#   'time_raw': 689.242},
#  {'idx': 1749,
#   'time': '00:11:29',
#   'Man': 'Eiji也太让人怀念了',
#   'content': 'エイジ懐かしすぎるわｗ',
#   'tBD': '太怀念了',
#   'tG': '好想念英二',
#   'tD': '年龄，你太怀旧了。',
#   'time_raw': 689.362},
#  {'idx': 1750,
#   'time': '00:11:29',
#   'Man': '初见！',
#   'content': '初見です！',
#   'tBD': '初次见面！',
#   'tG': '这是第一次！',
#   'tD': '我第一次看到它!',
#   'time_raw': 689.74},
#  {'idx': 1751,
#   'time': '00:11:30',
#   'Man': '好怀念',
#   'content': 'なつかしい',
#   'tBD': '怀念，眷念',
#   'tG': '怀旧',
#   'tD': '错过了',
#   'time_raw': 690.276},
#  {'idx': 1752,
#   'time': '00:11:30',
#   'Man': '噢噢噢噢',
#   'content': 'おおおお',
#   'tBD': '哦哦哦',
#   'tG': '哦哦',
#   'tD': '哦，哦，哦!',
#   'time_raw': 690.315},
#  {'idx': 1753,
#   'time': '00:11:30',
#   'Man': '过去在这里的女孩子',
#   'content': '過去にここにいた女の子か',
#   'tBD': '是过去在这里的女孩子吗',
#   'tG': '一个曾经在这里的女孩',
#   'tD': '你是过去在这里的那个女孩。',
#   'time_raw': 690.661},
#  {'idx': 1754,
#   'time': '00:11:32',
#   'Man': '这么老的作品 亏你知道啊',
#   'content': 'よく知ってるなそんな古い作品',
#   'tBD': '你知道吗',
#   'tG': '你知道那个老作品',
#   'tD': '你怎么知道这么古老的作品？',
#   'time_raw': 692.809},
#  {'idx': 1755,
#   'time': '00:11:33',
#   'Man': '有一个让人怀念的作品',
#   'content': 'また懐かしいやつを',
#   'tBD': '又怀念的家伙',
#   'tG': '另一个怀旧的',
#   'tD': '又一个怀旧的人。',
#   'time_raw': 693.298},
#  {'idx': 1756,
#   'time': '00:11:33',
#   'Man': '感应少女美兔的冒险谭',
#   'content': 'サイコメトラー美兎の冒険譚',
#   'tBD': '美兔的冒险谭',
#   'tG': '心理测量师比托的历险记',
#   'tD': '心理学家米-乌萨基的冒险》（The Adventures of Psychometra Mi-Uagi',
#   'time_raw': 693.464},
#  {'idx': 1757,
#   'time': '00:11:34',
#   'Man': '松冈君！',
#   'content': '松岡くん！！？',
#   'tBD': '松冈君！！？',
#   'tG': '松冈君！ ！ ?',
#   'tD': '松冈君！',
#   'time_raw': 694.057},
#  {'idx': 1758,
#   'time': '00:11:36',
#   'Man': '是老师啊',
#   'content': '先生か',
#   'tBD': '是老师吗',
#   'tG': '老师',
#   'tD': '医生',
#   'time_raw': 696.051},
#  {'idx': 1759,
#   'time': '00:11:37',
#   'Man': '信号灯是最近的',
#   'content': '信号機が最近のやつだ',
#   'tBD': '信号灯是最近的东西',
#   'tG': '红绿灯是最新的',
#   'tD': '交通灯是最近才设置的。',
#   'time_raw': 697.419},
#  {'idx': 1760,
#   'time': '00:11:37',
#   'Man': 'JK？',
#   'content': 'JK？',
#   'tBD': 'JK？',
#   'tG': 'JK？',
#   'tD': 'JK?',
#   'time_raw': 697.445},
#  {'idx': 1761,
#   'time': '00:11:40',
#   'Man': 'EIJI很老了',
#   'content': 'だいぶ古いんよEIJI',
#   'tBD': '很旧的EIJI',
#   'tG': 'EIJI很老了',
#   'tD': '这是非常古老的，EIJI。',
#   'time_raw': 700.678},
#  {'idx': 1762,
#   'time': '00:11:41',
#   'Man': '今天的梗都好老',
#   'content': 'すべてのネタが古いｗ',
#   'tBD': '所有的段子都很旧',
#   'tG': '所有的故事都是古老的',
#   'tD': '所有的故事都是老生常谈。',
#   'time_raw': 701.261},
#  {'idx': 1763,
#   'time': '00:11:43',
#   'Man': '不认识老师吗',
#   'content': '先生知らんのか',
#   'tBD': '老师你不知道吗',
#   'tG': '你认识老师吗',
#   'tD': '你不知道吗，医生？',
#   'time_raw': 703.332},
#  {'idx': 1764,
#   'time': '00:11:45',
#   'Man': '感应大便',
#   'content': 'ｳﾝｺﾒﾄﾗｰ',
#   'tBD': '大便测定器',
#   'tG': '取消注释',
#   'tD': '大便计量器',
#   'time_raw': 705.791},
#  {'idx': 1765,
#   'time': '00:11:45',
#   'Man': '今天是怀旧直播间？',
#   'content': '今日古のインターネット配信？',
#   'tBD': '今天旧的互联网送信？',
#   'tG': '今天的旧互联网交付？',
#   'tD': '今天的旧互联网分布？',
#   'time_raw': 705.791},
#  {'idx': 1767,
#   'time': '00:11:45',
#   'Man': '令人不安',
#   'content': '不穏だねぇ',
#   'tBD': '不稳啊',
#   'tG': '令人不安',
#   'tD': '这很令人不安。',
#   'time_raw': 705.942},
#  {'idx': 1769,
#   'time': '00:11:47',
#   'Man': '伪宅',
#   'content': 'イキリオタクに見えた',
#   'tBD': '看起来像伊基里奥塔克',
#   'tG': '看起来像个宅男',
#   'tD': '他看起来像一个ikkiyo书呆子。',
#   'time_raw': 707.575},
#  {'idx': 1770,
#   'time': '00:11:49',
#   'Man': '推理？',
#   'content': '推理もの？',
#   'tBD': '推理小说？',
#   'tG': '投机？',
#   'tD': '一个谜团？',
#   'time_raw': 709.067},
#  {'idx': 1771,
#   'time': '00:11:49',
#   'Man': '老师可爱',
#   'content': '先生かわいい',
#   'tBD': '老师很可爱',
#   'tG': '可爱的老师',
#   'tD': '可爱的老师',
#   'time_raw': 709.428},
#  {'idx': 1772,
#   'time': '00:11:49',
#   'Man': '唔呣？',
#   'content': 'ふむ？',
#   'tBD': '嗯？',
#   'tG': '嗯？',
#   'tD': '嗯？',
#   'time_raw': 709.898},
#  {'idx': 1773,
#   'time': '00:11:50',
#   'Man': '落在……对面了吗',
#   'content': '向こう側…落ちたか',
#   'tBD': '对面…掉下来了吗',
#   'tG': '另一边……掉下来了吗？',
#   'tD': '另一边......它倒下了。',
#   'time_raw': 710.03},
#  {'idx': 1774,
#   'time': '00:11:51',
#   'Man': '没太大变化',
#   'content': '変わりありませんなぁ',
#   'tBD': '没有变化啊',
#   'tG': '没有变化',
#   'tD': '没有变化。',
#   'time_raw': 711.513},
#  {'idx': 1775,
#   'time': '00:11:51',
#   'Man': '草',
#   'content': '草',
#   'tBD': '草本',
#   'tG': '草',
#   'tD': '草',
#   'time_raw': 711.58},
#  {'idx': 1776,
#   'time': '00:11:52',
#   'Man': '哎 有些emo',
#   'content': 'え、なんかエモい',
#   'tBD': '啊，总觉得很可爱',
#   'tG': '嗯，有点emo',
#   'tD': '呃，这有点儿情绪化。',
#   'time_raw': 712.511},
#  {'idx': 1777,
#   'time': '00:11:52',
#   'Man': '黑口罩好适合',
#   'content': '黒マスクお似合いです',
#   'tBD': '黑色口罩很适合您',
#   'tG': '我喜欢黑色面具',
#   'tD': '黑色面具很适合你。',
#   'time_raw': 712.596},
#  {'idx': 1778,
#   'time': '00:11:54',
#   'Man': '老师难道是',
#   'content': '先生まさか',
#   'tBD': '老师不会吧',
#   'tG': '没有老师',
#   'tD': '医生，没门！',
#   'time_raw': 714.482},
#  {'idx': 1779,
#   'time': '00:11:54',
#   'Man': '郡道老师！',
#   'content': '群道先生！',
#   'tBD': '群道老师！',
#   'tG': '群道先生！',
#   'tD': 'Gundo博士！',
#   'time_raw': 714.797},
#  {'idx': 1780,
#   'time': '00:11:56',
#   'Man': '有鞋子',
#   'content': 'くつあるね',
#   'tBD': '有鞋啊',
#   'tG': '有鞋子',
#   'tD': '鞋架',
#   'time_raw': 716.126},
#  {'idx': 1781,
#   'time': '00:11:58',
#   'Man': '游戏前面有说明hhh',
#   'content': 'ゲームの説明の先いっちゃってるｗ',
#   'tBD': '游戏的说明在前面',
#   'tG': '我已经过了游戏的解释了哈哈',
#   'tD': '我在游戏的描述中越来越超前。',
#   'time_raw': 718.275},
#  {'idx': 1782,
#   'time': '00:11:58',
#   'Man': '只有鞋子，啊...',
#   'content': '靴だけ、あっ・・・',
#   'tBD': '只有鞋子，啊',
#   'tG': '只有鞋子啊……',
#   'tD': '只有鞋子，啊...',
#   'time_raw': 718.526},
#  {'idx': 1783,
#   'time': '00:12:02',
#   'Man': '什么情况？',
#   'content': 'なんだ？',
#   'tBD': '什么啊？',
#   'tG': '什么？',
#   'tD': '它是什么？',
#   'time_raw': 722.407},
#  {'idx': 1784,
#   'time': '00:12:04',
#   'Man': '感应少年Eiji好怀念',
#   'content': 'サイコメトラーEIJIなっつ',
#   'tBD': '精神测量仪EIJI打印',
#   'tG': '心理测量师 EIJI Natsu',
#   'tD': '心理测绘师EIJI Natsu',
#   'time_raw': 724.17},
#  {'idx': 1786,
#   'time': '00:12:12',
#   'Man': '老师',
#   'content': 'センセイ',
#   'tBD': '海星',
#   'tG': '老师',
#   'tD': 'sensai（国家支持的医学协会，经常被用作医疗的借口）。',
#   'time_raw': 732.706},
#  {'idx': 1787,
#   'time': '00:12:12',
#   'Man': '掉到对面了吗',
#   'content': '向こう側に落ちたか',
#   'tBD': '掉到对面了吗',
#   'tG': '落在另一边',
#   'tD': '你落在了另一边。',
#   'time_raw': 732.74},
#  {'idx': 1788,
#   'time': '00:12:13',
#   'Man': '关系型宅宅信号灯',
#   'content': '関係性オタク信号機',
#   'tBD': '关系御宅族信号机',
#   'tG': '关系极客红绿灯',
#   'tD': '恋爱书呆子交通灯',
#   'time_raw': 733.216},
#  {'idx': 1789,
#   'time': '00:12:15',
#   'Man': '是这样',
#   'content': 'なるほど',
#   'tBD': '的确，的确',
#   'tG': '我懂了',
#   'tD': '我明白了',
#   'time_raw': 735.074},
#  {'idx': 1790,
#   'time': '00:12:16',
#   'Man': '好',
#   'content': '良いねえ',
#   'tBD': '好啊',
#   'tG': '好的',
#   'tD': '这很好。',
#   'time_raw': 736.977},
#  {'idx': 1791,
#   'time': '00:12:19',
#   'Man': '像素画和音乐都非常美极了 请享受最后',
#   'content': 'これドット絵と音がめちゃめちゃ綺麗で最後まで楽しめた',
#   'tBD': '这个点画和声音非常漂亮，一直享受到最后',
#   'tG': '这个像素艺术和声音太美了，我喜欢它直到最后',
#   'tD': '这些点和声音是如此美丽，以至于我一路走来都很享受。',
#   'time_raw': 739.824},
#  {'idx': 1792,
#   'time': '00:12:19',
#   'Man': '宗教？',
#   'content': '宗教か？',
#   'tBD': '宗教？',
#   'tG': '宗教？',
#   'tD': '宗教。',
#   'time_raw': 739.903},
#  {'idx': 1793,
#   'time': '00:12:22',
#   'Man': '原来如此',
#   'content': 'なるほど',
#   'tBD': '的确，的确',
#   'tG': '我懂了',
#   'tD': '我明白了',
#   'time_raw': 742.743},
#  {'idx': 1794,
#   'time': '00:12:24',
#   'Man': '奇妙的旅程开始了',
#   'content': '不思議な旅がはじまるのね',
#   'tBD': '不可思议的旅行开始了呢',
#   'tG': '奇妙的旅程开始了',
#   'tD': '于是开始了一段奇怪的旅程。',
#   'time_raw': 744.354},
#  {'idx': 1796,
#   'time': '00:12:26',
#   'Man': '啊啦^~',
#   'content': 'あら＾～',
#   'tBD': '哎呀',
#   'tG': '啊~~',
#   'tD': '哦，不^~。',
#   'time_raw': 746.434},
#  {'idx': 1797,
#   'time': '00:12:26',
#   'Man': '玻璃没有碎？',
#   'content': '窓割れてない？',
#   'tBD': '窗户没有碎？',
#   'tG': '窗户不是坏了吗？',
#   'tD': '是否有一扇破碎的窗户？',
#   'time_raw': 746.989},
#  {'idx': 1798,
#   'time': '00:12:28',
#   'Man': '呀~',
#   'content': 'はぇ〜',
#   'tBD': '哈哈～',
#   'tG': '呵呵~',
#   'tD': '呀。',
#   'time_raw': 748.939},
#  {'idx': 1799,
#   'time': '00:12:30',
#   'Man': '原来是这样',
#   'content': 'なるほどね',
#   'tBD': '原来如此啊',
#   'tG': '我懂了',
#   'tD': '我明白了。',
#   'time_raw': 750.106},
#  {'idx': 1800,
#   'time': '00:12:31',
#   'Man': '我战续',
#   'content': 'おれたた',
#   'tBD': '折边',
#   'tG': '奥雷塔',
#   'tD': '泪流满面',
#   'time_raw': 751.217},
#  {'idx': 1801,
#   'time': '00:12:31',
#   'Man': '原来如此',
#   'content': 'なるほど',
#   'tBD': '的确，的确',
#   'tG': '我懂了',
#   'tD': '我明白了',
#   'time_raw': 751.414},
#  {'idx': 1802,
#   'time': '00:12:34',
#   'Man': '老师……sayo教？',
#   'content': '先生……さよ教？',
#   'tBD': '老师……教？',
#   'tG': '老师……小夜？',
#   'tD': '...... Sayo Kyo博士？',
#   'time_raw': 754.498},
#  {'idx': 1803,
#   'time': '00:12:34',
#   'Man': '缺少了重要的部分',
#   'content': '重要な部分が欠落してるのね',
#   'tBD': '你缺少了重要的部分',
#   'tG': '你错过了一个重要的部分',
#   'tD': '你错过了一个重要的部分。',
#   'time_raw': 754.727},
#  {'idx': 1804,
#   'time': '00:12:36',
#   'Man': '这个游戏很有趣',
#   'content': 'このゲーム面白かった',
#   'tBD': '这个游戏很有趣',
#   'tG': '这个游戏很有趣',
#   'tD': '这个游戏很有趣。',
#   'time_raw': 756.635},
#  {'idx': 1805,
#   'time': '00:12:37',
#   'Man': '看了一小会就觉得是个好游戏',
#   'content': 'ちょっと見ただけで良ゲーの予感',
#   'tBD': '稍微看一下就有好的预感',
#   'tG': '只看一场好比赛的预感',
#   'tD': '我有一种感觉，这是个好游戏，只是看了一分钟。',
#   'time_raw': 757.808},
#  {'idx': 1806,
#   'time': '00:12:40',
#   'Man': '初见！',
#   'content': '初見です。！！！！！',
#   'tBD': '初次见面。！！！！！',
#   'tG': '第一次见。 ！ ！ ！ ！ ！',
#   'tD': '首次出现在: ！！！！！',
#   'time_raw': 760.659},
#  {'idx': 1807,
#   'time': '00:12:42',
#   'Man': '信号灯……',
#   'content': '信号機さん・・・（トゥンク）',
#   'tBD': '信号机先生……（图）',
#   'tG': '红绿灯... (Tunk)',
#   'tD': '信号员先生......（Tunku）。',
#   'time_raw': 762.51},
#  {'idx': 1808,
#   'time': '00:12:43',
#   'Man': '不知变通的信号灯',
#   'content': '融通がきかないな',
#   'tBD': '真是死脑筋',
#   'tG': '不灵活',
#   'tD': '你不是很灵活。',
#   'time_raw': 763.386},
#  {'idx': 1809,
#   'time': '00:12:44',
#   'Man': '头脑不灵活啊',
#   'content': '融通が利かないですね',
#   'tBD': '不灵活啊',
#   'tG': '我不灵活',
#   'tD': '我不是很灵活。',
#   'time_raw': 764.383},
#  {'idx': 1810,
#   'time': '00:12:48',
#   'Man': '哇，真是个麻烦的女人',
#   'content': 'うわ、めんどくさい女だ',
#   'tBD': '哇，真是个麻烦的女人',
#   'tG': '哇，好麻烦的女人',
#   'tD': '哇，她是个麻烦的家伙。',
#   'time_raw': 768.101},
#  {'idx': 1811,
#   'time': '00:12:49',
#   'Man': '见到老师的话会发生什么问题吗',
#   'content': '先生に会うと困ることでもあるのか？',
#   'tBD': '见到老师有什么困难吗？',
#   'tG': '你遇到你的老师有什么困难吗？',
#   'tD': '看医生有什么问题吗？',
#   'time_raw': 769.779},
#  {'idx': 1812,
#   'time': '00:12:53',
#   'Man': '监护人...？',
#   'content': '保護者…？',
#   'tBD': '监护人…？',
#   'tG': '保护者…？',
#   'tD': '监护人...？',
#   'time_raw': 773.307},
#  {'idx': 1813,
#   'time': '00:12:53',
#   'Man': '很坚定啊',
#   'content': 'つよいな',
#   'tBD': '强健',
#   'tG': '强的',
#   'tD': '伙计，这很难。',
#   'time_raw': 773.56},
#  {'idx': 1814,
#   'time': '00:12:54',
#   'Man': '不知变通的AI',
#   'content': '融通が利くAIだなｗ',
#   'tBD': '真是灵活的AI啊',
#   'tG': '这是灵活的人工智能。',
#   'tD': '你是一个灵活的人工智能。',
#   'time_raw': 774.23},
#  {'idx': 1815,
#   'time': '00:12:54',
#   'Man': '变异吧！！',
#   'content': '変異させようぜ!!',
#   'tBD': '让它变异吧！！',
#   'tG': '变异吧！！',
#   'tD': '让我们把它变异出来吧!',
#   'time_raw': 774.274},
#  {'idx': 1816,
#   'time': '00:12:54',
#   'Man': '好可爱',
#   'content': 'かわいい',
#   'tBD': '可爱，可爱',
#   'tG': '可爱的',
#   'tD': '可爱的',
#   'time_raw': 774.465},
#  {'idx': 1817,
#   'time': '00:12:54',
#   'Man': '可爱',
#   'content': '可愛い',
#   'tBD': '可爱，可爱',
#   'tG': '漂亮的',
#   'tD': '可爱的',
#   'time_raw': 774.479},
#  {'idx': 1818,
#   'time': '00:12:55',
#   'Man': '可爱',
#   'content': 'かわいい',
#   'tBD': '可爱，可爱',
#   'tG': '可爱的',
#   'tD': '可爱的',
#   'time_raw': 775.017},
#  {'idx': 1819,
#   'time': '00:12:55',
#   'Man': '真可爱',
#   'content': '顔真っ赤かよ',
#   'tBD': '脸通红啊',
#   'tG': '你的脸红了',
#   'tD': '你脸红了。',
#   'time_raw': 775.112},
#  {'idx': 1820,
#   'time': '00:12:55',
#   'Man': '做得到！',
#   'content': 'できらぁ！',
#   'tBD': '不行啊！',
#   'tG': '我能做到！',
#   'tD': '我可以做到!',
#   'time_raw': 775.44},
#  {'idx': 1821,
#   'time': '00:12:55',
#   'Man': '做得到！',
#   'content': 'できらぁ！',
#   'tBD': '不行啊！',
#   'tG': '我能做到！',
#   'tD': '我可以做到!',
#   'time_raw': 775.593},
#  {'idx': 1822,
#   'time': '00:12:55',
#   'Man': '好有感情',
#   'content': '感情あるのか',
#   'tBD': '有感情吗',
#   'tG': '你有感觉吗',
#   'tD': '你有感情。',
#   'time_raw': 775.623},
#  {'idx': 1823,
#   'time': '00:12:55',
#   'Man': '可爱',
#   'content': 'かわいい',
#   'tBD': '可爱，可爱',
#   'tG': '可爱的',
#   'tD': '可爱的',
#   'time_raw': 775.851},
#  {'idx': 1824,
#   'time': '00:12:56',
#   'Man': '可爱',
#   'content': 'かわいい',
#   'tBD': '可爱，可爱',
#   'tG': '可爱的',
#   'tD': '可爱的',
#   'time_raw': 776.145},
#  {'idx': 1825,
#   'time': '00:12:57',
#   'Man': '195可爱',
#   'content': '195かわいい',
#   'tBD': '195可爱',
#   'tG': '195可爱',
#   'tD': '195个可爱的。',
#   'time_raw': 777.127},
#  {'idx': 1826,
#   'time': '00:12:57',
#   'Man': '做得到！',
#   'content': 'できまぁす！',
#   'tBD': '可以！',
#   'tG': '我能做到！',
#   'tD': '我可以做到!',
#   'time_raw': 777.254},
#  {'idx': 1827,
#   'time': '00:12:57',
#   'Man': '可爱',
#   'content': 'かわいい',
#   'tBD': '可爱，可爱',
#   'tG': '可爱的',
#   'tD': '可爱的',
#   'time_raw': 777.314},
#  {'idx': 1828,
#   'time': '00:12:57',
#   'Man': '做得到！',
#   'content': 'できらぁ！',
#   'tBD': '不行啊！',
#   'tG': '我能做到！',
#   'tD': '我可以做到!',
#   'time_raw': 777.334},
#  {'idx': 1829,
#   'time': '00:12:57',
#   'Man': '草',
#   'content': '草',
#   'tBD': '草本',
#   'tG': '草',
#   'tD': '草',
#   'time_raw': 777.379},
#  {'idx': 1830,
#   'time': '00:12:57',
#   'Man': '好哄',
#   'content': '煽りよる',
#   'tBD': '煽动',
#   'tG': '惹',
#   'tD': '煽动',
#   'time_raw': 777.653},
#  {'idx': 1831,
#   'time': '00:12:57',
#   'Man': '真好骗hhh',
#   'content': 'ちょろいw',
#   'tBD': '有点小w',
#   'tG': '易w',
#   'tD': '软W',
#   'time_raw': 777.816},
#  {'idx': 1832,
#   'time': '00:12:57',
#   'Man': '做得到！',
#   'content': 'できらぁ！',
#   'tBD': '不行啊！',
#   'tG': '我能做到！',
#   'tD': '我可以做到!',
#   'time_raw': 777.876},
#  {'idx': 1833,
#   'time': '00:12:57',
#   'Man': '可爱',
#   'content': 'かわいい',
#   'tBD': '可爱，可爱',
#   'tG': '可爱的',
#   'tD': '可爱的',
#   'time_raw': 777.951},
#  {'idx': 1834,
#   'time': '00:12:58',
#   'Man': '可爱',
#   'content': 'かわいい',
#   'tBD': '可爱，可爱',
#   'tG': '可爱的',
#   'tD': '可爱的',
#   'time_raw': 778.052},
#  {'idx': 1835,
#   'time': '00:12:58',
#   'Man': '别激人家啊hhh',
#   'content': '煽るなｗ',
#   'tBD': '不要煽动',
#   'tG': '不要挑衅',
#   'tD': '不要搅乱了锅。',
#   'time_raw': 778.118},
#  {'idx': 1836,
#   'time': '00:12:58',
#   'Man': '做得到！',
#   'content': 'できらぁ！',
#   'tBD': '不行啊！',
#   'tG': '我能做到！',
#   'tD': '我可以做到!',
#   'time_raw': 778.51},
#  {'idx': 1837,
#   'time': '00:12:58',
#   'Man': '这家伙好可爱啊',
#   'content': 'こいつかわいいな',
#   'tBD': '这家伙真可爱',
#   'tG': '这家伙很可爱',
#   'tD': '这家伙很可爱。',
#   'time_raw': 778.565},
#  {'idx': 1838,
#   'time': '00:12:58',
#   'Man': '１９５草',
#   'content': '１９５草',
#   'tBD': '195草',
#   'tG': '１９５草',
#   'tD': '195 Sedum rupifragum(石竹的种类)',
#   'time_raw': 778.574},
#  {'idx': 1839,
#   'time': '00:12:58',
#   'Man': '可爱',
#   'content': 'かわいい',
#   'tBD': '可爱，可爱',
#   'tG': '可爱的',
#   'tD': '可爱的',
#   'time_raw': 778.588},
#  {'idx': 1840,
#   'time': '00:12:58',
#   'Man': '做得到！',
#   'content': 'できらぁ！',
#   'tBD': '不行啊！',
#   'tG': '我能做到！',
#   'tD': '我可以做到!',
#   'time_raw': 778.617},
#  {'idx': 1841,
#   'time': '00:12:58',
#   'Man': '做得到！',
#   'content': 'できらぁ！！',
#   'tBD': '不行啊！！',
#   'tG': '我能做到！ ！',
#   'tD': '我可以做到!',
#   'time_raw': 778.62},
#  {'idx': 1842,
#   'time': '00:12:58',
#   'Man': '很像人',
#   'content': '人間っぽいなｗ',
#   'tBD': '真像人类啊w',
#   'tG': '很像人',
#   'tD': '你很有人性。',
#   'time_raw': 778.805},
#  {'idx': 1843,
#   'time': '00:12:58',
#   'Man': '做得到！',
#   'content': 'できらぁ！',
#   'tBD': '不行啊！',
#   'tG': '我能做到！',
#   'tD': '我可以做到!',
#   'time_raw': 778.809},
#  {'idx': 1844,
#   'time': '00:12:58',
#   'Man': '好好好可爱~',
#   'content': 'かわぃぃぃ',
#   'tBD': '我爱你',
#   'tG': '可爱的',
#   'tD': 'Kawaii',
#   'time_raw': 778.863},
#  {'idx': 1845,
#   'time': '00:12:59',
#   'Man': '做得到！',
#   'content': 'できまぁす！',
#   'tBD': '可以！',
#   'tG': '我能做到！',
#   'tD': '我可以做到!',
#   'time_raw': 779.393},
#  {'idx': 1846,
#   'time': '00:12:59',
#   'Man': '可爱hhh',
#   'content': 'かわいいw',
#   'tBD': '好可爱w',
#   'tG': '可爱的 w',
#   'tD': '可爱的W。',
#   'time_raw': 779.393},
#  {'idx': 1847,
#   'time': '00:12:59',
#   'Man': '195太可爱了hhh',
#   'content': '195かわいすぎんかw',
#   'tBD': '195太可爱了w',
#   'tG': '195太可爱了w',
#   'tD': '195 这不是太可爱了吗？',
#   'time_raw': 779.574},
#  {'idx': 1848,
#   'time': '00:12:59',
#   'Man': '草',
#   'content': '草',
#   'tBD': '草本',
#   'tG': '草',
#   'tD': '草',
#   'time_raw': 779.616},
#  {'idx': 1849,
#   'time': '00:12:59',
#   'Man': '可爱',
#   'content': 'かわいい',
#   'tBD': '可爱，可爱',
#   'tG': '可爱的',
#   'tD': '可爱的',
#   'time_raw': 779.645},
#  {'idx': 1850,
#   'time': '00:12:59',
#   'Man': '可爱的信号灯hhh',
#   'content': 'かわいい信号機ｗ',
#   'tBD': '可爱的信号机w',
#   'tG': '可爱的红绿灯',
#   'tD': '可爱的交通灯',
#   'time_raw': 779.783},
#  {'idx': 1851,
#   'time': '00:12:59',
#   'Man': '做得到！',
#   'content': 'できらぁ！',
#   'tBD': '不行啊！',
#   'tG': '我能做到！',
#   'tD': '我可以做到!',
#   'time_raw': 779.785},
#  {'idx': 1852,
#   'time': '00:12:59',
#   'Man': '真好哄',
#   'content': 'ちょろいｗ',
#   'tBD': '有点小w',
#   'tG': '易w',
#   'tD': '软W',
#   'time_raw': 779.861},
#  {'idx': 1853,
#   'time': '00:12:59',
#   'Man': '真好哄',
#   'content': '煽りによわい',
#   'tBD': '经不起煽动',
#   'tG': '容易受到挑衅',
#   'tD': '弱智',
#   'time_raw': 779.898},
#  {'idx': 1854,
#   'time': '00:12:59',
#   'Man': '冷静点195！',
#   'content': '落ち着いて195！！',
#   'tBD': '冷静点195！！',
#   'tG': '冷静195！ ！',
#   'tD': '平静下来，195！',
#   'time_raw': 779.945},
#  {'idx': 1855,
#   'time': '00:13:00',
#   'Man': '好萌啊',
#   'content': '萌えじゃん',
#   'tBD': '很萌吧',
#   'tG': '萌简',
#   'tD': '这就是 "萌"。',
#   'time_raw': 780.255},
#  {'idx': 1856,
#   'time': '00:13:00',
#   'Man': '像是小笨蛋',
#   'content': 'ポンコツそう',
#   'tBD': '冲孔槽',
#   'tG': '废话',
#   'tD': '笨重的 "日本纸桑（Broussonetia kazinoki x papyrifera）"。',
#   'time_raw': 780.269},
#  {'idx': 1857,
#   'time': '00:13:00',
#   'Man': '可爱',
#   'content': 'かわいい',
#   'tBD': '可爱，可爱',
#   'tG': '可爱的',
#   'tD': '可爱的',
#   'time_raw': 780.447},
#  {'idx': 1858,
#   'time': '00:13:00',
#   'Man': '做得到！',
#   'content': 'できらぁ！',
#   'tBD': '不行啊！',
#   'tG': '我能做到！',
#   'tD': '我可以做到!',
#   'time_raw': 780.48},
#  {'idx': 1859,
#   'time': '00:13:00',
#   'Man': '有点像是小糸',
#   'content': '小糸ちゃんみたいだな',
#   'tBD': '像小丝一样啊',
#   'tG': '你长得像小糸',
#   'tD': '你的声音像小藤。',
#   'time_raw': 780.706},
#  {'idx': 1860,
#   'time': '00:13:00',
#   'Man': '做得到！',
#   'content': 'できらぁ！',
#   'tBD': '不行啊！',
#   'tG': '我能做到！',
#   'tD': '我可以做到!',
#   'time_raw': 780.717},
#  {'idx': 1861,
#   'time': '00:13:00',
#   'Man': '做得到！！',
#   'content': 'できらぁ！！',
#   'tBD': '不行啊！！',
#   'tG': '我能做到！ ！',
#   'tD': '我可以做到!',
#   'time_raw': 780.869},
#  {'idx': 1862,
#   'time': '00:13:01',
#   'Man': '可爱',
#   'content': 'かわいい',
#   'tBD': '可爱，可爱',
#   'tG': '可爱的',
#   'tD': '可爱的',
#   'time_raw': 781.393},
#  {'idx': 1863,
#   'time': '00:13:01',
#   'Man': '好可爱',
#   'content': 'かわいいな',
#   'tBD': '好可爱啊',
#   'tG': '可爱的',
#   'tD': '可爱。',
#   'time_raw': 781.91},
#  {'idx': 1864,
#   'time': '00:13:02',
#   'Man': '可爱',
#   'content': 'かわいい',
#   'tBD': '可爱，可爱',
#   'tG': '可爱的',
#   'tD': '可爱的',
#   'time_raw': 782.329},
#  {'idx': 1865,
#   'time': '00:13:03',
#   'Man': '经不起激',
#   'content': '煽り耐性なし',
#   'tBD': '没有煽动性',
#   'tG': '没有挑逗性',
#   'tD': '无可救药',
#   'time_raw': 783.498},
#  {'idx': 1866,
#   'time': '00:13:03',
#   'Man': '笨比好可爱',
#   'content': 'ポンコツかわいい',
#   'tBD': '胖乎乎的可爱',
#   'tG': '笨拙可爱',
#   'tD': '笨重但可爱',
#   'time_raw': 783.517},
#  {'idx': 1867,
#   'time': '00:13:03',
#   'Man': '可爱——',
#   'content': 'かわいいー',
#   'tBD': '好可爱啊',
#   'tG': '可爱的',
#   'tD': '多么可爱!',
#   'time_raw': 783.605},
#  {'idx': 1868,
#   'time': '00:13:03',
#   'Man': '可爱',
#   'content': 'かわあい',
#   'tBD': '哇哦',
#   'tG': '可爱的',
#   'tD': '染工结草（Persicaria tinctoria，用于生产靛蓝染料）',
#   'time_raw': 783.637},
#  {'idx': 1869,
#   'time': '00:13:03',
#   'Man': '温柔',
#   'content': '優しい',
#   'tBD': '温柔的',
#   'tG': '种类',
#   'tD': '温文尔雅',
#   'time_raw': 783.676},
#  {'idx': 1870,
#   'time': '00:13:03',
#   'Man': '经不起激的信号灯',
#   'content': '煽りに弱い信号機',
#   'tBD': '不耐煽动的信号机',
#   'tG': '容易受到挑衅的信号',
#   'tD': '交通灯容易加重。',
#   'time_raw': 783.759},
#  {'idx': 1871,
#   'time': '00:13:03',
#   'Man': '做得到！',
#   'content': 'できらぁ！',
#   'tBD': '不行啊！',
#   'tG': '我能做到！',
#   'tD': '我可以做到!',
#   'time_raw': 783.847},
#  {'idx': 1872,
#   'time': '00:13:03',
#   'Man': '是萌系角色啊',
#   'content': '萌キャラじゃん',
#   'tBD': '不是萌角色吗',
#   'tG': '萌字',
#   'tD': '萌萌哒的性格!',
#   'time_raw': 783.993},
#  {'idx': 1873,
#   'time': '00:13:04',
#   'Man': '这家伙经不起激啊',
#   'content': '煽り耐性ないぞこいつ',
#   'tBD': '这家伙没有煽动性',
#   'tG': '这家伙没有耐心逗弄',
#   'tD': '他并不激动，这家伙。',
#   'time_raw': 784.115},
#  {'idx': 1874,
#   'time': '00:13:04',
#   'Man': '感觉笨笨的~',
#   'content': 'ポンコツ感ある',
#   'tBD': '有蓬松感',
#   'tG': '有种笨拙的感觉',
#   'tD': '它感觉很笨重。',
#   'time_raw': 784.115},
#  {'idx': 1875,
#   'time': '00:13:04',
#   'Man': '可爱',
#   'content': 'かわいい',
#   'tBD': '可爱，可爱',
#   'tG': '可爱的',
#   'tD': '可爱的',
#   'time_raw': 784.586},
#  {'idx': 1876,
#   'time': '00:13:05',
#   'Man': '这就是高性能。',
#   'content': 'これは高性能',
#   'tBD': '这是高性能的',
#   'tG': '这是高性能',
#   'tD': '这就是高性能。',
#   'time_raw': 785.295},
#  {'idx': 1877,
#   'time': '00:13:05',
#   'Man': '可爱',
#   'content': 'かわいい',
#   'tBD': '可爱，可爱',
#   'tG': '可爱的',
#   'tD': '可爱的',
#   'time_raw': 785.474},
#  {'idx': 1878,
#   'time': '00:13:05',
#   'Man': '可爱',
#   'content': 'かわいい',
#   'tBD': '可爱，可爱',
#   'tG': '可爱的',
#   'tD': '可爱的',
#   'time_raw': 785.764},
#  {'idx': 1879,
#   'time': '00:13:05',
#   'Man': '可爱',
#   'content': 'かわいい',
#   'tBD': '可爱，可爱',
#   'tG': '可爱的',
#   'tD': '可爱的',
#   'time_raw': 785.959},
#  {'idx': 1880,
#   'time': '00:13:06',
#   'Man': '草',
#   'content': '草',
#   'tBD': '草本',
#   'tG': '草',
#   'tD': '草',
#   'time_raw': 786.362},
#  {'idx': 1881,
#   'time': '00:13:06',
#   'Man': '可爱',
#   'content': 'かわいい',
#   'tBD': '可爱，可爱',
#   'tG': '可爱的',
#   'tD': '可爱的',
#   'time_raw': 786.787},
#  {'idx': 1882,
#   'time': '00:13:07',
#   'Man': '195好可耐',
#   'content': '195かわええな',
#   'tBD': '195好可爱啊',
#   'tG': '195可爱',
#   'tD': '195个可爱的。',
#   'time_raw': 787.004},
#  {'idx': 1883,
#   'time': '00:13:07',
#   'Man': '（撒了谎）',
#   'content': '（嘘をつきました）',
#   'tBD': '（撒了谎）',
#   'tG': '（我撒了谎）',
#   'tD': '(被骗了)。',
#   'time_raw': 787.18},
#  {'idx': 1884,
#   'time': '00:13:07',
#   'Man': '195可爱',
#   'content': '195かわいい',
#   'tBD': '195可爱',
#   'tG': '195可爱',
#   'tD': '195个可爱的。',
#   'time_raw': 787.668},
#  {'idx': 1885,
#   'time': '00:13:07',
#   'Man': '195是个可爱的家伙w',
#   'content': '195くんかわいいやつだなｗ',
#   'tBD': '195君真可爱啊w',
#   'tG': '195是个可爱的家伙w',
#   'tD': '195，你是个可爱的小家伙，不是吗？',
#   'time_raw': 787.698},
#  {'idx': 1886,
#   'time': '00:13:07',
#   'Man': '有效果了有效果了……hhh',
#   'content': '効いてる効いてる…w',
#   'tBD': '很有效…w',
#   'tG': '它的工作，它的工作... w',
#   'tD': '它在工作，它在工作...W',
#   'time_raw': 787.8},
#  {'idx': 1887,
#   'time': '00:13:07',
#   'Man': '做得到！！！',
#   'content': 'できまぁあす！',
#   'tBD': '明天可以！',
#   'tG': '我明天可以做！',
#   'tD': '我可以做到!',
#   'time_raw': 787.894},
#  {'idx': 1888,
# ...
#   'content': '新人バイトくんさぁ…',
#   'tBD': '新人打工君来吧…',
#   'tG': '新人打工君...',
#   'tD': '嘿，新来的兼职者...',
#   'time_raw': 1138.805},
#  {'idx': 2521,
#   'time': '00:18:59',
#   'Man': '新人也不会的吧',
#   'content': '新人ならしゃーない',
#   'tBD': '不是新人',
#   'tG': '如果您是新手，请不要担心',
#   'tD': '如果你是新人就不会。',
#   'time_raw': 1139.039},
#  {'idx': 2522,
#   'time': '00:18:59',
#   'Man': '嘛没留心的话就不会记得的吧',
#   'content': 'まぁ気にしてないと覚えないよね',
#   'tBD': '嘛，不介意的话就不记得了吧',
#   'tG': '好吧，如果你不在乎，你就不会记得',
#   'tD': '好吧，如果你不关心，你就不会记得。',
#   'time_raw': 1139.847},
#  {'idx': 2523,
#   'time': '00:19:00',
#   'Man': '好可爱啊',
#   'content': 'かわいいなぁ',
#   'tBD': '好可爱啊',
#   'tG': '可爱的',
#   'tD': '你太可爱了。',
#   'time_raw': 1140.398},
#  {'idx': 2524,
#   'time': '00:19:00',
#   'Man': '好单纯',
#   'content': 'おちゃめだ',
#   'tBD': '淘气，淘气',
#   'tG': '你在开玩笑',
#   'tD': '迷人。',
#   'time_raw': 1140.697},
#  {'idx': 2525,
#   'time': '00:19:01',
#   'Man': '刚开始打工这说法好有趣',
#   'content': '入りたてのバイトは言い得て妙だなw',
#   'tBD': '刚进入的打工说起来很奇怪啊',
#   'tG': '奇怪的是刚入职的兼职是w',
#   'tD': '俗话说，你是个刚出道的打工仔。',
#   'time_raw': 1141.086},
#  {'idx': 2526,
#   'time': '00:19:01',
#   'Man': '笨比啊',
#   'content': 'ポンコツがよぉ',
#   'tBD': '砰的一声',
#   'tG': '这是一个垃圾',
#   'tD': '他妈的一坨屎。',
#   'time_raw': 1141.568},
#  {'idx': 2527,
#   'time': '00:19:01',
#   'Man': '笨~笨笨',
#   'content': 'ポポンポン',
#   'tBD': '波蓬',
#   'tG': '蓬蓬蓬',
#   'tD': '鲳鱼',
#   'time_raw': 1141.627},
#  {'idx': 2528,
#   'time': '00:19:01',
#   'Man': '草',
#   'content': '草',
#   'tBD': '草本',
#   'tG': '草',
#   'tD': '草',
#   'time_raw': 1141.752},
#  {'idx': 2529,
#   'time': '00:19:01',
#   'Man': '冒失鬼捏',
#   'content': 'どじっこね',
#   'tBD': '地脚螺钉',
#   'tG': '童子根',
#   'tD': '顽皮的孩子',
#   'time_raw': 1141.831},
#  {'idx': 2530,
#   'time': '00:19:02',
#   'Man': '好可爱啊hhh',
#   'content': 'かわいいなｗ',
#   'tBD': '好可爱啊w',
#   'tG': '可爱的',
#   'tD': '你很可爱。',
#   'time_raw': 1142.588},
#  {'idx': 2531,
#   'time': '00:19:02',
#   'Man': '草',
#   'content': '草',
#   'tBD': '草本',
#   'tG': '草',
#   'tD': '草',
#   'time_raw': 1142.59},
#  {'idx': 2532,
#   'time': '00:19:02',
#   'Man': '冒失鬼！！',
#   'content': 'ドジっ子が！！',
#   'tBD': '冒失鬼！！',
#   'tG': '笨拙！ ！',
#   'tD': '你是个混蛋!',
#   'time_raw': 1142.656},
#  {'idx': 2533,
#   'time': '00:19:02',
#   'Man': '不要欺负新人哦',
#   'content': '新入りいじめるなよ',
#   'tBD': '不要欺负新人',
#   'tG': '不要欺负新人',
#   'tD': '不要欺负新来的人。',
#   'time_raw': 1142.755},
#  {'idx': 2534,
#   'time': '00:19:04',
#   'Man': '真好啊195',
#   'content': 'めっちゃいいな195くん',
#   'tBD': '超好的195君',
#   'tG': '超级好看的195君',
#   'tD': '非常好，195先生。',
#   'time_raw': 1144.532},
#  {'idx': 2535,
#   'time': '00:19:04',
#   'Man': '说过了有什么事情要告诉我吧？',
#   'content': 'なんかあったら言ってって言ったよね？',
#   'tBD': '你不是说有什么事就告诉我吗？',
#   'tG': '我让你告诉我如果发生了什么事，不是吗？',
#   'tD': '我告诉过你，如果有什么不对，就告诉我，不是吗？',
#   'time_raw': 1144.533},
#  {'idx': 2536,
#   'time': '00:19:04',
#   'Man': '不好意思 是新人信号灯……',
#   'content': 'すいません新しくできた信号機なんで・・・',
#   'tBD': '对不起，这是新建成的信号灯',
#   'tG': '对不起，这是一个新的信号...',
#   'tD': '对不起，这是一个新的交通灯...',
#   'time_raw': 1144.629},
#  {'idx': 2537,
#   'time': '00:19:04',
#   'Man': '但是也没有问有没有看到乌鸦……',
#   'content': 'でもカラス見たかって聞かれなかったし…',
#   'tBD': '但是没人问我看到乌鸦了吗…',
#   'tG': '但他们没有问我是否想看乌鸦...',
#   'tD': '但他们没有问我是否看到任何乌鸦......',
#   'time_raw': 1144.786},
#  {'idx': 2538,
#   'time': '00:19:06',
#   'Man': '冒失鬼AI',
#   'content': 'ドジっ子AI',
#   'tBD': '矮子AI',
#   'tG': '笨拙的人工智能',
#   'tD': '笨拙的人工智能',
#   'time_raw': 1146.208},
#  {'idx': 2539,
#   'time': '00:19:06',
#   'Man': '打工君啊……',
#   'content': 'バイトくんさぁ',
#   'tBD': '打工君来吧',
#   'tG': '兼职工作',
#   'tD': '来吧，兼职的人。',
#   'time_raw': 1146.69},
#  {'idx': 2540,
#   'time': '00:19:07',
#   'Man': '是不是不问就不会说的那种类型啊hh',
#   'content': '聞かれたことしか言わないタイプかなｗ',
#   'tBD': '是只说被问到的话的类型吧',
#   'tG': '你是那种只说你被问到的人吗？',
#   'tD': '我想我是那种只告诉别人他们问我什么的人。',
#   'time_raw': 1147.515},
#  {'idx': 2541,
#   'time': '00:19:08',
#   'Man': '打工hhh',
#   'content': 'バイトw',
#   'tBD': '字节w',
#   'tG': '字节 w',
#   'tD': '字节W。',
#   'time_raw': 1148.0},
#  {'idx': 2542,
#   'time': '00:19:08',
#   'Man': '而且你把左和右都搞错了!',
#   'content': '右と左も間違えるしよお！！',
#   'tBD': '右边和左边都弄错了哦！！',
#   'tG': '不要混淆左右！ ！',
#   'tD': '而且你把左和右都搞错了!',
#   'time_raw': 1148.906},
#  {'idx': 2543,
#   'time': '00:19:09',
#   'Man': '果然还是笨比啊',
#   'content': 'やっぱりポンコツ',
#   'tBD': '果然是破烂',
#   'tG': '毕竟废话',
#   'tD': '它仍然是一个破烂。',
#   'time_raw': 1149.007},
#  {'idx': 2544,
#   'time': '00:19:09',
#   'Man': '便利！',
#   'content': '便利！',
#   'tBD': '方便！',
#   'tG': '方便的！',
#   'tD': '方便!',
#   'time_raw': 1149.744},
#  {'idx': 2545,
#   'time': '00:19:09',
#   'Man': '可爱',
#   'content': 'かわいい',
#   'tBD': '可爱，可爱',
#   'tG': '可爱的',
#   'tD': '可爱的',
#   'time_raw': 1149.784},
#  {'idx': 2546,
#   'time': '00:19:10',
#   'Man': '有能',
#   'content': 'ぐう有能',
#   'tBD': '全能',
#   'tG': '很有天赋',
#   'tD': '很能干',
#   'time_raw': 1150.531},
#  {'idx': 2547,
#   'time': '00:19:11',
#   'Man': '好meta',
#   'content': 'メタい',
#   'tBD': '偏位',
#   'tG': '元',
#   'tD': '元',
#   'time_raw': 1151.522},
#  {'idx': 2548,
#   'time': '00:19:11',
#   'Man': 'meta meta',
#   'content': 'メタいメタい',
#   'tBD': '偏位',
#   'tG': '元元',
#   'tD': '金属',
#   'time_raw': 1151.787},
#  {'idx': 2550,
#   'time': '00:19:12',
#   'Man': '好厉害',
#   'content': '有能じゃん',
#   'tBD': '有能力嘛',
#   'tG': '才华横溢',
#   'tD': '你是一个有能力的人。',
#   'time_raw': 1152.266},
#  {'idx': 2551,
#   'time': '00:19:12',
#   'Man': '打工可不能重要的事憋着不说啊',
#   'content': '大事な事黙ってるタイプのバイトまじで使えん',
#   'tBD': '重要的事沉默的类型的打工真的不能使用',
#   'tG': '我不能把它当作对重要事情保持沉默的那种兼职工作',
#   'tD': '那种对重要事情保持沉默的兼职人员是严重的无用之人。',
#   'time_raw': 1152.835},
#  {'idx': 2552,
#   'time': '00:19:13',
#   'Man': '温柔的meta',
#   'content': 'メタい優しさ',
#   'tBD': '超温柔',
#   'tG': '元善',
#   'tD': '元仁',
#   'time_raw': 1153.648},
#  {'idx': 2553,
#   'time': '00:19:13',
#   'Man': '有能',
#   'content': 'ぐう有能',
#   'tBD': '全能',
#   'tG': '很有天赋',
#   'tD': '很能干',
#   'time_raw': 1153.945},
#  {'idx': 2554,
#   'time': '00:19:14',
#   'Man': '这就是高性能',
#   'content': 'これは高性能',
#   'tBD': '这是高性能的',
#   'tG': '这是高性能',
#   'tD': '这就是高性能。',
#   'time_raw': 1154.18},
#  {'idx': 2555,
#   'time': '00:19:14',
#   'Man': '195又能',
#   'content': '１９５有能',
#   'tBD': '195能力',
#   'tG': '195 称职',
#   'tD': '195 胜任的。',
#   'time_raw': 1154.372},
#  {'idx': 2556,
#   'time': '00:19:14',
#   'Man': '冒失鬼？',
#   'content': 'おっポンコツか？？',
#   'tBD': '哦，是诀窍吗？？',
#   'tG': '哎呀？ ?',
#   'tD': '哇，一辆破车？',
#   'time_raw': 1154.602},
#  {'idx': 2557,
#   'time': '00:19:14',
#   'Man': '哦哦',
#   'content': 'おお',
#   'tBD': '大的',
#   'tG': '哦',
#   'tD': '哦!',
#   'time_raw': 1154.942},
#  {'idx': 2558,
#   'time': '00:19:15',
#   'Man': '噢 meta meta',
#   'content': 'おぉメタいメタい',
#   'tBD': '极性',
#   'tG': '哦元元',
#   'tD': '哦，meta-meta-meta。',
#   'time_raw': 1155.451},
#  {'idx': 2559,
#   'time': '00:19:15',
#   'Man': '你这家伙来决定的吗hhh',
#   'content': 'お前が決めるのかw',
#   'tBD': '是你决定的吗',
#   'tG': '你决定',
#   'tD': '你是一个决定者。',
#   'time_raw': 1155.895},
#  {'idx': 2560,
#   'time': '00:19:15',
#   'Man': '你做信号灯第几年了？',
#   'content': 'お前信号何年目だよ',
#   'tBD': '你的信号灯多少年了',
#   'tG': '你的信号几岁了？',
#   'tD': '你已经做了多少年的信号工作？',
#   'time_raw': 1155.911},
#  {'idx': 2561,
#   'time': '00:19:15',
#   'Man': '真棒',
#   'content': 'えらい',
#   'tBD': '了不起',
#   'tG': '伟大的',
#   'tD': '杰出的',
#   'time_raw': 1155.911},
#  {'idx': 2562,
#   'time': '00:19:16',
#   'Man': 'meta',
#   'content': 'メメタァ',
#   'tBD': '甲基丙胺',
#   'tG': '模因',
#   'tD': '匹卡',
#   'time_raw': 1156.076},
#  {'idx': 2563,
#   'time': '00:19:16',
#   'Man': '你来展示吗',
#   'content': 'お前が表示してたんか',
#   'tBD': '是你显示的吗',
#   'tG': '你有没有展示',
#   'tD': '你就是那个展示它的人。',
#   'time_raw': 1156.191},
#  {'idx': 2564,
#   'time': '00:19:17',
#   'Man': '感谢',
#   'content': 'ありがたい',
#   'tBD': '谢天谢地',
#   'tG': '赞赏',
#   'tD': '感谢',
#   'time_raw': 1157.694},
#  {'idx': 2565,
#   'time': '00:19:17',
#   'Man': '方便',
#   'content': '便利',
#   'tBD': '方便',
#   'tG': '方便的',
#   'tD': '方便',
#   'time_raw': 1157.977},
#  {'idx': 2566,
#   'time': '00:19:18',
#   'Man': '真好啊这个演出',
#   'content': 'いいねこの演出',
#   'tBD': '这个演出很好',
#   'tG': '我喜欢这个制作',
#   'tD': '我喜欢这部作品。',
#   'time_raw': 1158.86},
#  {'idx': 2567,
#   'time': '00:19:19',
#   'Man': '太又能了草',
#   'content': '有能すぎて草',
#   'tBD': '太能干了',
#   'tG': '太有才草',
#   'tD': '太能干了，草木皆兵。',
#   'time_raw': 1159.008},
#  {'idx': 2568,
#   'time': '00:19:19',
#   'Man': '有点meta',
#   'content': 'ややメタ',
#   'tBD': '稍微元',
#   'tG': '有点元',
#   'tD': '有点玄学',
#   'time_raw': 1159.52},
#  {'idx': 2569,
#   'time': '00:19:19',
#   'Man': '成长了',
#   'content': '成長した',
#   'tBD': '成长的',
#   'tG': '长大的',
#   'tD': '长大了。',
#   'time_raw': 1159.676},
#  {'idx': 2571,
#   'time': '00:19:20',
#   'Man': '可以改进hhh',
#   'content': '改善できるんかw',
#   'tBD': '能改善吗',
#   'tG': '你能改进吗',
#   'tD': '可以改进吗？',
#   'time_raw': 1160.497},
#  {'idx': 2572,
#   'time': '00:19:22',
#   'Man': "YES! Iinchou's playing this game!",
#   'content': "YES! Iinchou's playing this game!",
#   'tBD': "YES! Iinchou's playing this game!",
#   'tG': '是的！仁州在玩这个游戏！',
#   'tD': '是的，英秋在玩这个游戏。',
#   'time_raw': 1162.536},
#  {'idx': 2573,
#   'time': '00:19:24',
#   'Man': 'meta',
#   'content': 'メタい',
#   'tBD': '偏位',
#   'tG': '元',
#   'tD': '元',
#   'time_raw': 1164.115},
#  {'idx': 2574,
#   'time': '00:19:24',
#   'Man': '做得好棒',
#   'content': '作り込みすごい',
#   'tBD': '做得很厉害',
#   'tG': '做工很棒',
#   'tD': '它的结构之好令人惊讶。',
#   'time_raw': 1164.452},
#  {'idx': 2575,
#   'time': '00:19:24',
#   'Man': '195是镇上的AI，不是吗？',
#   'content': '１９５は町にいるAIなんじゃない？',
#   'tBD': '195不是在镇上的AI吗？',
#   'tG': '195不是城里的AI吗？',
#   'tD': '195是镇上的AI，不是吗？',
#   'time_raw': 1164.587},
#  {'idx': 2576,
#   'time': '00:19:26',
#   'Man': '要上了！',
#   'content': 'ｲｸｿﾞｰ！',
#   'tBD': '好爽！',
#   'tG': '生三！',
#   'tD': 'Ixzo!',
#   'time_raw': 1166.688},
#  {'idx': 2577,
#   'time': '00:19:26',
#   'Man': '嗯——高性能',
#   'content': 'うーん高性能',
#   'tBD': '嗯高性能',
#   'tG': '嗯高性能',
#   'tD': '嗯，高性能',
#   'time_raw': 1166.851},
#  {'idx': 2578,
#   'time': '00:19:27',
#   'Man': '一同成长吧',
#   'content': '一緒に成長しよう',
#   'tBD': '一起成长吧',
#   'tG': '让我们一起成长',
#   'tD': '让我们一起成长。',
#   'time_raw': 1167.466},
#  {'idx': 2579,
#   'time': '00:19:29',
#   'Man': 'UI也是195制作的吗',
#   'content': 'UI195が作ってるのか',
#   'tBD': '是UI195做的吗',
#   'tG': '是UI195做的吗？',
#   'tD': 'UI 195正在制作。',
#   'time_raw': 1169.069},
#  {'idx': 2580,
#   'time': '00:19:29',
#   'Man': '一直是红灯啊这家伙',
#   'content': 'ずっと赤だなこの信号',
#   'tBD': '一直都是红色的这个信号',
#   'tG': '此信号始终为红色',
#   'tD': '一路都是红灯，这个交通灯。',
#   'time_raw': 1169.82},
#  {'idx': 2581,
#   'time': '00:19:30',
#   'Man': '有导航吗？',
#   'content': 'ガイドいるぅ？',
#   'tBD': '有导游吗？',
#   'tG': '你有导游吗？',
#   'tD': '你需要一个向导吗？',
#   'time_raw': 1170.554},
#  {'idx': 2582,
#   'time': '00:19:32',
#   'Man': '可以的吗？',
#   'content': 'それいる？',
#   'tBD': '有那个吗？',
#   'tG': '你有吗？',
#   'tD': '那是在那里吗？',
#   'time_raw': 1172.683},
#  {'idx': 2583,
#   'time': '00:19:36',
#   'Man': '恭喜！',
#   'content': 'おめでとう！',
#   'tBD': '恭喜恭喜！',
#   'tG': '恭喜！',
#   'tD': '祝贺你!',
#   'time_raw': 1176.428},
#  {'idx': 2584,
#   'time': '00:19:36',
#   'Man': '195的设定是谁做的啊！我要狠狠夸夸你！',
#   'content': '195のキャラ決めたやつは誰だ！\u3000褒めてつかわす！',
#   'tBD': '决定了195的角色的家伙是谁！我会表扬你的！',
#   'tG': '谁决定了195的性格！赞美和发送！',
#   'tD': '谁决定的195个字符！？\u3000我会把这当作一种赞美!',
#   'time_raw': 1176.437},
#  {'idx': 2585,
#   'time': '00:19:36',
#   'Man': '就这样随波逐流',
#   'content': '受け流すかぁ',
#   'tBD': '就这样随波逐流',
#   'tG': '我要招架吗',
#   'tD': '我就不去管它了。',
#   'time_raw': 1176.483},
#  {'idx': 2586,
#   'time': '00:19:36',
#   'Man': '草',
#   'content': '草',
#   'tBD': '草本',
#   'tG': '草',
#   'tD': '草',
#   'time_raw': 1176.56},
#  {'idx': 2587,
#   'time': '00:19:36',
#   'Man': '好可爱啊',
#   'content': 'かわいいなぁ',
#   'tBD': '好可爱啊',
#   'tG': '可爱的',
#   'tD': '你太可爱了。',
#   'time_raw': 1176.844},
#  {'idx': 2588,
#   'time': '00:19:37',
#   'Man': '太好了',
#   'content': 'よかったね',
#   'tBD': '太好了',
#   'tG': '对你有益',
#   'tD': '对你有好处。',
#   'time_raw': 1177.107},
#  {'idx': 2589,
#   'time': '00:19:37',
#   'Man': '没有这个也完全没问题吧',
#   'content': 'こいつもういなくていいんじゃないか？',
#   'tBD': '这家伙不在也没关系吧？',
#   'tG': '这家伙不应该在这里吗？',
#   'tD': '他不需要再呆在这里了，对吗？',
#   'time_raw': 1177.21},
#  {'idx': 2590,
#   'time': '00:19:37',
#   'Man': '草',
#   'content': '草',
#   'tBD': '草本',
#   'tG': '草',
#   'tD': '草',
#   'time_raw': 1177.394},
#  {'idx': 2591,
#   'time': '00:19:38',
#   'Man': '→_→ hhh',
#   'content': 'ジト目w',
#   'tBD': '吉特目w',
#   'tG': 'w',
#   'tD': '一个女人的眼睛...',
#   'time_raw': 1178.745},
#  {'idx': 2593,
#   'time': '00:19:38',
#   'Man': '草',
#   'content': '草',
#   'tBD': '草本',
#   'tG': '草',
#   'tD': '草',
#   'time_raw': 1178.865},
#  {'idx': 2594,
#   'time': '00:19:39',
#   'Man': '过分',
#   'content': 'ひどい',
#   'tBD': '残酷的',
#   'tG': '糟糕的',
#   'tD': '严重',
#   'time_raw': 1179.19},
#  {'idx': 2595,
#   'time': '00:19:39',
#   'Man': '成长中的AI君',
#   'content': '成長するAIくんちゃん',
#   'tBD': '成长的AI君',
#   'tG': '成长中的艾坤灿',
#   'tD': '长大了，AI-kun-chan。',
#   'time_raw': 1179.585},
#  {'idx': 2596,
#   'time': '00:19:39',
#   'Man': '草',
#   'content': '草',
#   'tBD': '草本',
#   'tG': '草',
#   'tD': '草',
#   'time_raw': 1179.682},
#  {'idx': 2597,
#   'time': '00:19:42',
#   'Man': '好棒的组合',
#   'content': 'いいコンビだw',
#   'tBD': '很好的组合',
#   'tG': '这是一个很好的组合w',
#   'tD': '这是一个很好的组合。',
#   'time_raw': 1182.313},
#  {'idx': 2598,
#   'time': '00:19:42',
#   'Man': 'meta发言出现了',
#   'content': 'ダメ出しキタ',
#   'tBD': '出渣器',
#   'tG': '糟糕的北边',
#   'tD': "'不，不，不，不'。",
#   'time_raw': 1182.763},
#  {'idx': 2599,
#   'time': '00:19:43',
#   'Man': '太喜欢这个AI了',
#   'content': '愛おしいなこのAI',
#   'tBD': '可爱的AI',
#   'tG': '这个可爱的AI',
#   'tD': '这个AI很可爱。',
#   'time_raw': 1183.582},
#  {'idx': 2600,
#   'time': '00:19:43',
#   'Man': '{{{(>_<)}}}',
#   'content': 'しょんぼり',
#   'tBD': '垂头丧气',
#   'tG': '郁闷',
#   'tD': '心灰意冷',
#   'time_raw': 1183.71},
#  {'idx': 2601,
#   'time': '00:19:44',
#   'Man': '可爱',
#   'content': 'かわいい',
#   'tBD': '可爱，可爱',
#   'tG': '可爱的',
#   'tD': '可爱的',
#   'time_raw': 1184.507},
#  {'idx': 2602,
#   'time': '00:19:45',
#   'Man': '可爱',
#   'content': 'かわいい',
#   'tBD': '可爱，可爱',
#   'tG': '可爱的',
#   'tD': '可爱的',
#   'time_raw': 1185.088},
#  {'idx': 2603,
#   'time': '00:19:45',
#   'Man': '草',
#   'content': '草',
#   'tBD': '草本',
#   'tG': '草',
#   'tD': '草',
#   'time_raw': 1185.508},
#  {'idx': 2604,
#   'time': '00:19:45',
#   'Man': '要是这个样子的195变成了敌人 不要啊……',
#   'content': '195がこの感じで敵だったらやだな…',
#   'tBD': '195如果是敌人的话就好了…',
#   'tG': '我希望195是这样的敌人......',
#   'tD': '如果195年是这样的敌人，我就不喜欢了......。',
#   'time_raw': 1185.564},
#  {'idx': 2605,
#   'time': '00:19:45',
#   'Man': '有艾希的味道',
#   'content': 'アイシー味ある',
#   'tBD': '有爱西味',
#   'tG': '有冰凉的味道',
#   'tD': '冰冷的',
#   'time_raw': 1185.651},
#  {'idx': 2606,
#   'time': '00:19:45',
#   'Man': '草',
#   'content': '草',
#   'tBD': '草本',
#   'tG': '草',
#   'tD': '草',
#   'time_raw': 1185.958},
#  {'idx': 2607,
#   'time': '00:19:46',
#   'Man': '好冷淡',
#   'content': '冷たいなぁ',
#   'tBD': '好冷啊',
#   'tG': '是冷的',
#   'tD': '这很冷。',
#   'time_raw': 1186.447},
#  {'idx': 2609,
#   'time': '00:19:47',
#   'Man': '有紧急情况吗',
#   'content': '緊急時があるのか',
#   'tBD': '有紧急情况吗',
#   'tG': '有紧急情况吗',
#   'tD': '是否有紧急情况？',
#   'time_raw': 1187.623},
#  {'idx': 2610,
#   'time': '00:19:47',
#   'Man': '真棒',
#   'content': 'いいね',
#   'tBD': '不错啊',
#   'tG': '多好',
#   'tD': '很好。',
#   'time_raw': 1187.951},
#  {'idx': 2611,
#   'time': '00:19:48',
#   'Man': '有紧急情况吗',
#   'content': '緊急時があるのか',
#   'tBD': '有紧急情况吗',
#   'tG': '有紧急情况吗',
#   'tD': '是否有紧急情况？',
#   'time_raw': 1188.277},
#  {'idx': 2612,
#   'time': '00:19:48',
#   'Man': '情绪稍有点低落',
#   'content': 'ちょっとテンション下がったｗ',
#   'tBD': '情绪有点低落了',
#   'tG': '少一点紧张',
#   'tD': '我有点不太兴奋。',
#   'time_raw': 1188.378},
#  {'idx': 2613,
#   'time': '00:19:48',
#   'Man': '一起成长吧',
#   'content': '一緒に成長していこうな',
#   'tBD': '一起成长吧',
#   'tG': '让我们一起成长',
#   'tD': '我们将一起成长。',
#   'time_raw': 1188.995},
#  {'idx': 2614,
#   'time': '00:19:50',
#   'Man': '草',
#   'content': '草',
#   'tBD': '草本',
#   'tG': '草',
#   'tD': '草',
#   'time_raw': 1190.141},
#  {'idx': 2615,
#   'time': '00:19:51',
#   'Man': '可爱',
#   'content': 'かわいい',
#   'tBD': '可爱，可爱',
#   'tG': '可爱的',
#   'tD': '可爱的',
#   'time_raw': 1191.01},
#  {'idx': 2617,
#   'time': '00:19:51',
#   'Man': '这两人的关系真好啊hh',
#   'content': 'この二人の関係いいなぁww',
#   'tBD': '这两个人的关系真好啊ww',
#   'tG': '哇这两个关系很好',
#   'tD': '我喜欢他们的关系。',
#   'time_raw': 1191.254},
#  {'idx': 2618,
#   'time': '00:19:51',
#   'Man': '(´·ω·｀)',
#   'content': '(´・ω・｀)',
#   'tBD': '（´·ω・‘）',
#   'tG': '(´·ω·｀)',
#   'tD': '(译者注)。',
#   'time_raw': 1191.795},
#  {'idx': 2619,
#   'time': '00:19:51',
#   'Man': '总感觉好可爱',
#   'content': 'なんかかわいそう',
#   'tBD': '总觉得可怜',
#   'tG': '我为你感到难过',
#   'tD': '我为你感到难过。',
#   'time_raw': 1191.892},
#  {'idx': 2620,
#   'time': '00:19:52',
#   'Man': '可爱',
#   'content': 'かわいい',
#   'tBD': '可爱，可爱',
#   'tG': '可爱的',
#   'tD': '可爱的',
#   'time_raw': 1192.152},
#  {'idx': 2621,
#   'time': '00:19:52',
#   'Man': '出现了新的好tag',
#   'content': 'いいタッグ感出てきた',
#   'tBD': '感觉很好',
#   'tG': '一个好的标签感觉出来了',
#   'tD': '开始感觉到这是一个好的标签团队。',
#   'time_raw': 1192.441},
#  {'idx': 2622,
#   'time': '00:19:52',
#   'Man': '会有紧急情况啊……',
#   'content': '緊急時があるんですね…',
#   'tBD': '有紧急情况啊…',
#   'tG': '我有一个紧急情况...',
#   'tD': '你有一个紧急情况...',
#   'time_raw': 1192.488},
#  {'idx': 2623,
#   'time': '00:19:52',
#   'Man': '草',
#   'content': '草',
#   'tBD': '草本',
#   'tG': '草',
#   'tD': '草',
#   'time_raw': 1192.628},
#  ...]

# %%
len(curr_frame_new_comments)
# Out:
# 1016

# %%
from utils import SegmentDanmakuCommentManager
segment_danmaku_comment_manager_config = {
                'layout': 'danmaku',
                'n_tracks': 13,
                'start_time': 0,
                'end_time': -1,
                'font_name': './PingFang SC Bold.ttf',
                'font_size': 40,
                'speed_y': 0,
                # 'speed_x': '-2.5x',
                'speed_x': -5,
                'stroke_width': 3,
                'stroke_fill': (0,0,0,1),
                'track_y_start': 60,
                'track_y_margin': 10,
                'video_H': 1080,
                'video_W': 1920,
                'time_offset': start_time_min*60
            }
segment_danmaku_comment_manager = SegmentDanmakuCommentManager(segment_danmaku_comment_manager_config)

# %%
import cv2 as cv
cv.CAP_PROP_POS_FRAMES
# Out:
# 1

# %%
# [python - Getting timestamp of each frame in a video - Stack Overflow](https://stackoverflow.com/questions/47743246/getting-timestamp-of-each-frame-in-a-video)
# [opencv - how to get frames with timestamp where frames are converted from video in python - Stack Overflow](https://stackoverflow.com/questions/51129425/how-to-get-frames-with-timestamp-where-frames-are-converted-from-video-in-python)
# [python opencv get camera frame timestamp in system time accurately - Stack Overflow](https://stackoverflow.com/questions/55069809/python-opencv-get-camera-frame-timestamp-in-system-time-accurately)
# [OpenCV: Getting Started with Videos](https://docs.opencv.org/4.x/dd/d43/tutorial_py_video_display.html)
# [python opencv videocapture get time of frame - Google Search](https://www.google.com/search?q=python+opencv+videocapture+get+time+of+frame&sxsrf=ALiCzsbFdt2ou5k1JDCRk3kwG7mDtqrdXg%3A1665100064912&ei=IGk_Y_GIN93R5NoPuY6D6Ac&ved=0ahUKEwjxmImP5cz6AhXdKFkFHTnHAH0Q4dUDCA4&uact=5&oq=python+opencv+videocapture+get+time+of+frame&gs_lcp=Cgdnd3Mtd2l6EAMyCAghEB4QFhAdOgoIABBHENYEELADOgQIABBDOgUIABCABDoICAAQgAQQywE6BggAEB4QFjoFCAAQhgM6BQghEKABOgUIIRCrAjoHCCEQoAEQCkoFCDwSATFKBAhNGAFKBAhBGABKBAhGGABQrwhYuCBgxCFoAXABeACAAXiIAb8MkgEEMTcuMZgBAKABAcgBCMABAQ&sclient=gws-wiz)
# [Getting specific frames from VideoCapture opencv in python - Stack Overflow](https://stackoverflow.com/questions/33523751/getting-specific-frames-from-videocapture-opencv-in-python)

mode = 'vis'
# mode = 'dry_run'
# mode = 'save'

from utils import CommentDrawer
import numpy as np
from pathlib import Path
import cv2 as cv
# cap = cv.VideoCapture("../code_add_comments/piece_1_no_comment.mp4")
cap = cv.VideoCapture("../piece1/piece1-lost-sec-no-caption.mp4")
fps = cap.get(cv.CAP_PROP_FPS)
n_total_frames = int(cap.get(cv.CAP_PROP_FRAME_COUNT))
# timestamps = [cap.get(cv.CAP_PROP_POS_MSEC)]
calc_timestamps = [0.0]

# https://stackoverflow.com/questions/33523751/getting-specific-frames-from-videocapture-opencv-in-python

start_frame = start_time_min * 60 *fps
cap.set(cv.CAP_PROP_POS_FRAMES, start_frame)
# comment_pool.set_point_to_time(start_time_min*60, 0)

# Define the codec and create VideoWriter object
if mode == 'save':
    # fourcc = cv.VideoWriter_fourcc(*'XVID')
    # out = cv.VideoWriter('./test_piece_flip.avi', fourcc, 20.0, (640,  480))
    # https://stackoverflow.com/questions/28163201/writing-a-video-file-using-h-264-compression-in-opencv
    # https://stackoverflow.com/questions/61260182/how-to-output-x265-compressed-video-with-cv2-videowriter
    fourcc = cv.VideoWriter_fourcc(*'MP4V')
    # fourcc = cv.VideoWriter_fourcc('a','v','c','1')
    # fourcc = cv.VideoWriter_fourcc(*'H265')
    out = cv.VideoWriter(r'C:\Users\remus\Desktop\piece_1_no_caption_with_Danmaku.mp4', fourcc, fps, (1920,1080))
n_minutes = -1
n_frame = int(n_minutes*60*fps) if n_minutes != -1 else n_total_frames
frame_idx = 0 
curr_frame_time = start_time_min*60 + 0.0

comment_drawer_config = {
    # 'text_key': 'content',    
    'font_name': './PingFang SC Bold.ttf',    
    'use_text_mask': False
}
comment_drawer = CommentDrawer(comment_drawer_config)

text_mask = cv.imread(str('./test_text_mask-6.png'))
text_mask = text_mask.astype(float)/255
# comment_drawer.text_mask = np.ones_like(text_mask)
comment_drawer.text_mask = text_mask
# comment_drawer.text_mask = np.zeros_like(text_mask)


import sys
from time import sleep
from tqdm import tqdm

# while cap.isOpened():
# values = range(3)
all_comment_speeds = []
a = 0
try:
    # print('AAAAAAAAA')
    with tqdm(total=min(n_total_frames, n_frame), file=sys.stdout) as pbar:
    # with a=1:
        for frame_idx in range(min(n_total_frames, n_frame)):
            pbar.set_description('frame: %d' % (1 + frame_idx))
            pbar.update(1)
            # sleep(1)

            if n_frame > 0 and frame_idx > n_frame and not cap.isOpened():
                break

            ret, frame = cap.read()
            if not ret:
                print("Can't receive frame (stream end?). Exiting ...")
                break
            else:
                # timestamps.append(cap.get(cv.CAP_PROP_POS_MSEC))
                # calc_timestamps.append(calc_timestamps[-1] + 1/fps)
                curr_frame_time += 1/fps
            
            # if frame_idx == 0:
            print(curr_frame_time)
            
            curr_frame_new_comments = comment_pool.get_new_comments_before_time(curr_frame_time)
            # if len(curr_frame_new_comments) > 0:
                # print(curr_frame_new_comments)
            # print(frame_idx, len(curr_frame_new_comments))
            segment_danmaku_comment_manager.update_loaded_comments(curr_frame_new_comments, n_comment_limit=10)
            curr_frame_comments = segment_danmaku_comment_manager.get_loaded_comments()

            for track in segment_danmaku_comment_manager.tracks:
                all_comment_speeds += [c.speed_x for c in track.comments]

            if mode != 'dry_run':
                img_with_text = comment_drawer.draw_on_frame(frame, curr_frame_comments)
            else:
                img_with_text = frame
            
            if mode == 'save':
                out.write(img_with_text)
            elif mode == 'vis':
                cv.imshow('frame', img_with_text)
            elif mode == 'dry_run':
                pass
            if cv.waitKey(1) == ord('q'):
                break
    cv.destroyAllWindows()
    cap.release()
    if mode == 'save':
        out.release()
except KeyboardInterrupt:
    cv.destroyAllWindows()
    cap.release()
    if mode == 'save':
        out.release()
        # frame_idx += 1
# Release everything if job is finished

# cv.destroyAllWindows()
# Out:
# frame: 1:   0%|          | 0/53920 [00:00<?, ?it/s]600.0333409497481
# frame: 2:   0%|          | 2/53920 [00:00<1:08:45, 13.07it/s]600.0666818994962
# frame: 3:   0%|          | 2/53920 [00:00<1:08:45, 13.07it/s]600.1000228492443
# frame: 4:   0%|          | 4/53920 [00:00<1:05:42, 13.67it/s]600.1333637989924
# frame: 5:   0%|          | 4/53920 [00:00<1:05:42, 13.67it/s]600.1667047487405
# frame: 6:   0%|          | 6/53920 [00:00<1:08:32, 13.11it/s]600.2000456984886
# frame: 7:   0%|          | 6/53920 [00:00<1:08:32, 13.11it/s]600.2333866482367
# frame: 8:   0%|          | 8/53920 [00:00<1:09:36, 12.91it/s]600.2667275979848
# frame: 9:   0%|          | 8/53920 [00:00<1:09:36, 12.91it/s]600.3000685477328
# frame: 10:   0%|          | 10/53920 [00:00<1:09:51, 12.86it/s]600.333409497481
# frame: 11:   0%|          | 10/53920 [00:00<1:09:51, 12.86it/s]600.366750447229
# frame: 12:   0%|          | 12/53920 [00:00<1:10:14, 12.79it/s]600.4000913969771
# frame: 13:   0%|          | 12/53920 [00:01<1:10:14, 12.79it/s]600.4334323467252
# frame: 14:   0%|          | 14/53920 [00:01<1:10:42, 12.71it/s]600.4667732964733
# frame: 15:   0%|          | 14/53920 [00:01<1:10:42, 12.71it/s]600.5001142462214
# frame: 16:   0%|          | 16/53920 [00:01<1:10:26, 12.75it/s]600.5334551959695
# frame: 17:   0%|          | 16/53920 [00:01<1:10:26, 12.75it/s]600.5667961457176
# frame: 18:   0%|          | 18/53920 [00:01<1:08:25, 13.13it/s]600.6001370954657
# frame: 19:   0%|          | 18/53920 [00:01<1:08:25, 13.13it/s]600.6334780452138
# frame: 20:   0%|          | 20/53920 [00:01<1:07:12, 13.37it/s]600.6668189949619
# frame: 21:   0%|          | 20/53920 [00:01<1:07:12, 13.37it/s]600.70015994471
# frame: 22:   0%|          | 22/53920 [00:01<1:04:01, 14.03it/s]600.7335008944581
# frame: 23:   0%|          | 22/53920 [00:01<1:04:01, 14.03it/s]600.7668418442062
# frame: 24:   0%|          | 24/53920 [00:01<1:03:49, 14.08it/s]600.8001827939543
# frame: 25:   0%|          | 24/53920 [00:01<1:03:49, 14.08it/s]600.8335237437024
# frame: 26:   0%|          | 26/53920 [00:01<1:06:08, 13.58it/s]600.8668646934505
# frame: 27:   0%|          | 26/53920 [00:02<1:06:08, 13.58it/s]600.9002056431985
# frame: 28:   0%|          | 28/53920 [00:02<1:07:27, 13.31it/s]600.9335465929466
# frame: 29:   0%|          | 28/53920 [00:02<1:07:27, 13.31it/s]600.9668875426947
# frame: 30:   0%|          | 30/53920 [00:02<1:08:02, 13.20it/s]601.0002284924428
# frame: 31:   0%|          | 30/53920 [00:02<1:08:02, 13.20it/s]601.0335694421909
# frame: 32:   0%|          | 32/53920 [00:02<1:12:06, 12.46it/s]601.066910391939
# frame: 33:   0%|          | 32/53920 [00:02<1:12:06, 12.46it/s]601.1002513416871
# frame: 34:   0%|          | 34/53920 [00:02<1:18:06, 11.50it/s]601.1335922914352
# frame: 35:   0%|          | 34/53920 [00:02<1:18:06, 11.50it/s]601.1669332411833
# frame: 36:   0%|          | 36/53920 [00:02<1:13:52, 12.16it/s]601.2002741909314
# frame: 36:   0%|          | 36/53920 [00:02<1:11:14, 12.61it/s]

# %%
curr_frame_time
# Out:
# 601.2002741909314

# %%
curr_frame_time + comment_pool.time_offset
# Out:
# 1201.2002741909314

# %%
comment_pool.pointer
# Out:
# 2535

# %%
comment_pool.comments[comment_pool.pointer]#['time_raw']
# Out:
# {'idx': 2642,
#  'time': '00:20:03',
#  'Man': '？',
#  'content': '？',
#  'tBD': '？',
#  'tG': '？',
#  'tD': '?',
#  'time_raw': 1203.313}

# %%
curr_frame_time
# Out:
# 602.3005255326185

# %%
segment_danmaku_comment_manager.get_loaded_comments()[0].content
# Out:
# '自我意识啊'
